# %%
# Data import
import pyomo.environ as pe
import math

# Data
factories = ["IJmuiden", "Segal", "South Wales"]
rebars = {"A": {"length": 2.4}, "B": {"length": 3.6}, "C": {"length": 4.2}}
longbars = {1: {"length": 9}, 2: {"length": 12}}
diameter = 0.057  # in meters
density = 7.85  # tons/m^3
production_capacity = {"IJmuiden": 12, "Segal": 10, "South Wales": 28}
customers = ["Bochum", "Boenen", "Dortmund", "Gelsenkirchen", "Hagen", "Iserlohn", "Neuss", "Schwerte"]
periods = [1, 2, 3, 4]

demand = {
    "A": {
        "Bochum": [2, 6, 5, 3],
        "Boenen": [4, 8, 5, 10],
        "Dortmund": [2, 7, 6, 5],
        "Gelsenkirchen": [5, 5, 5, 5],
        "Hagen": [19, 23, 25, 16],
        "Iserlohn": [13, 19, 17, 14],
        "Neuss": [20, 16, 14, 26],
        "Schwerte": [4, 5, 3, 4]
    },
    "B": {
        "Bochum": [4, 5, 7, 8],
        "Boenen": [5, 8, 12, 13],
        "Dortmund": [4, 5, 8, 10],
        "Gelsenkirchen": [9, 10, 6, 6],
        "Hagen": [15, 33, 31, 33],
        "Iserlohn": [22, 26, 20, 27],
        "Neuss": [12, 23, 30, 30],
        "Schwerte": [2, 8, 2, 6]
    },
    "C": {
        "Bochum": [6, 7, 7, 7],
        "Boenen": [6, 10, 15, 12],
        "Dortmund": [7, 6, 4, 12],
        "Gelsenkirchen": [10, 9, 9, 10],
        "Hagen": [12, 35, 33, 38],
        "Iserlohn": [14, 25, 23, 24],
        "Neuss": [22, 32, 31, 31],
        "Schwerte": [5, 6, 7, 2]
    }
}

fixed_cost = {"IJmuiden": 130, "Segal": 150, "South Wales": 100}
v = 0.5  # variable cost €/km/tonne
distance = {
    "Bochum": {"IJmuiden": 250, "Segal": 203, "South Wales": 866},
    "Boenen": {"IJmuiden": 282, "Segal": 242, "South Wales": 914},
    "Dortmund": {"IJmuiden": 266, "Segal": 222, "South Wales": 885},
    "Gelsenkirchen": {"IJmuiden": 234, "Segal": 198, "South Wales": 859},
    "Hagen": {"IJmuiden": 289, "Segal": 206, "South Wales": 903},
    "Iserlohn": {"IJmuiden": 299, "Segal": 226, "South Wales": 913},
    "Neuss": {"IJmuiden": 259, "Segal": 140, "South Wales": 843},
    "Schwerte": {"IJmuiden": 279, "Segal": 216, "South Wales": 901}
}

# Precompute parameters
w_r = {r: rebars[r]["length"] for r in rebars}
w_l = {l: longbars[l]["length"] for l in longbars}
area = math.pi * (diameter / 2) ** 2


# possible number of long bars per long bar type per factory 
N = {
    1: {"IJmuiden": 67, "Segal": 56, "South Wales": 156},
    2: {"IJmuiden": 50, "Segal": 42, "South Wales": 117}
}

possible_longbars = {} 

for l in longbars:
    possible_longbars[l] = {} 
    for f in factories:
        possible_longbars[l][f] = list(range(1, N.get(l, {}).get(f, 0) + 1))

# Defining big M
# List to store total demand per customer
total_demand_per_customer = []

# Loop over each customer
for a in customers:
    total_demand = sum(demand[r][a][t-1] for r in rebars for t in periods)  # Sum over all rebars and periods
    total_demand_per_customer.append(total_demand)

# Get the maximum demand across all customers
M = max(total_demand_per_customer)

inventory_capacity = {
    "Bochum": 10,
    "Boenen": 7,
    "Dortmund": 12,
    "Gelsenkirchen": 10,
    "Hagen": 12,
    "Iserlohn": 9,
    "Neuss": 8,
    "Schwerte": 5
}

# %%
#New data for 3: 
distanceq3 = {
    "IJmuiden": {"IJmuiden": 0, "Segal": 284, "South Wales": 826, "Bochum": 250, "Boenen": 282, "Dortmund": 266, "Gelsenkirchen": 234, "Hagen": 289, "Iserlohn": 299, "Neuss": 259, "Schwerte": 279},
    "Segal": {"IJmuiden": 284, "Segal": 0, "South Wales": 750, "Bochum": 203, "Boenen": 242, "Dortmund": 222, "Gelsenkirchen": 198, "Hagen": 206, "Iserlohn": 226, "Neuss": 140, "Schwerte": 216},
    "South Wales": {"IJmuiden": 826, "Segal": 750, "South Wales": 0, "Bochum": 866, "Boenen": 914, "Dortmund": 885, "Gelsenkirchen": 859, "Hagen": 903, "Iserlohn": 913, "Neuss": 843, "Schwerte": 901},
    "Bochum": {"IJmuiden": 250, "Segal": 203, "South Wales": 866, "Bochum": 0, "Boenen": 55, "Dortmund": 21, "Gelsenkirchen": 19, "Hagen": 41, "Iserlohn": 51, "Neuss": 56, "Schwerte": 39},
    "Boenen": {"IJmuiden": 282, "Segal": 242, "South Wales": 914, "Bochum": 55, "Boenen": 0, "Dortmund": 34, "Gelsenkirchen": 56, "Hagen": 44, "Iserlohn": 54, "Neuss": 102, "Schwerte": 32},
    "Dortmund": {"IJmuiden": 266, "Segal": 222, "South Wales": 885, "Bochum": 21, "Boenen": 34, "Dortmund": 0, "Gelsenkirchen": 34, "Hagen": 21, "Iserlohn": 36, "Neuss": 75, "Schwerte": 15},
    "Gelsenkirchen": {"IJmuiden": 234, "Segal": 198, "South Wales": 859, "Bochum": 19, "Boenen": 56, "Dortmund": 34, "Gelsenkirchen": 0, "Hagen": 56, "Iserlohn": 66, "Neuss": 62, "Schwerte": 54},
    "Hagen": {"IJmuiden": 289, "Segal": 206, "South Wales": 903, "Bochum": 41, "Boenen": 44, "Dortmund": 21, "Gelsenkirchen": 56, "Hagen": 0, "Iserlohn": 20, "Neuss": 66, "Schwerte": 14},
    "Iserlohn": {"IJmuiden": 299, "Segal": 226, "South Wales": 913, "Bochum": 51, "Boenen": 54, "Dortmund": 36, "Gelsenkirchen": 66, "Hagen": 20, "Iserlohn": 0, "Neuss": 85, "Schwerte": 15},
    "Neuss": {"IJmuiden": 259, "Segal": 140, "South Wales": 843, "Bochum": 56, "Boenen": 102, "Dortmund": 75, "Gelsenkirchen": 62, "Hagen": 66, "Iserlohn": 85, "Neuss": 0, "Schwerte": 75},
    "Schwerte": {"IJmuiden": 279, "Segal": 216, "South Wales": 901, "Bochum": 39, "Boenen": 32, "Dortmund": 15, "Gelsenkirchen": 54, "Hagen": 14, "Iserlohn": 15, "Neuss": 75, "Schwerte": 0}
}

#Vehicle capacity
Q = 25
# Cost per km
C = 3

model3 = pe.ConcreteModel()

# Initialize sets for model 2
model3.F = pe.Set(initialize=factories)
model3.R = pe.Set(initialize=rebars.keys())
model3.L = pe.Set(initialize=longbars.keys())
model3.A = pe.Set(initialize=customers)
model3.T = pe.Set(initialize=periods)
model3.F_A = model3.F | model3.A
model3.A_f = pe.Set(model3.F, initialize=lambda model3, f: model3.A | {f})
#model3.C = pe.Set(model3.A, model3.T, within=model3.A, initialize=lambda model, a, t: [])


valid_x_indices = []
for l in possible_longbars:
    for f in possible_longbars[l]:
        for n in possible_longbars[l][f]:  # Only valid values of n
            valid_x_indices.append((l, n, f))

# Create an indexed set for (L, F, N)
model3.L_N_F = pe.Set(dimen=3, initialize=valid_x_indices)

# Define variables
model3.x = pe.Var(model3.R, model3.L_N_F,  model3.T, domain=pe.NonNegativeIntegers)
model3.y = pe.Var(model3.L_N_F, model3.T, domain=pe.Binary)
model3.z = pe.Var(model3.F, model3.A, model3.T, domain=pe.Binary, initialize = 0)
model3.i = pe.Var(model3.A, model3.R, model3.T, domain=pe.NonNegativeIntegers)
model3.q = pe.Var(model3.R, model3.F, model3.A, model3.T, domain=pe.NonNegativeIntegers, initialize = 0)

# Define the valid indices for model3.v dynamically
#valid_v_indices = [(f, A_f, A_f, t) for f in model3.F for t in model3.T for A_f in model3.A_f[f]]
valid_v_indices = [
    (f, A_f_source, A_f_dest, t)
    for f in model3.F
    for t in model3.T
    for A_f_source in model3.A_f[f]
    for A_f_dest in model3.A_f[f]
]

# Add new variables to model3
model3.v = pe.Var(model3.F_A, model3.F_A, model3.T, domain=pe.Binary, initialize=0)
#model3.v = pe.Var(valid_v_indices, domain=pe.Binary, initialize = 0)
model3.u = pe.Var(model3.A, model3.F, model3.T, domain=pe.NonNegativeIntegers, initialize = 0)

# Add notation for t_fat and z_fat for simplicity
# Define t_fat as the tonnes shipped from factory f to customer a in period t
model3.t = pe.Expression(model3.F, model3.A, model3.T, 
                                  rule=lambda model3, f, a, t: 
                                  sum(model3.q[(r, f, a, t)] * w_r[r] * density * area for r in model3.R))
      
#model3.z = pe.Expression(model3.F, model3.A, model3.T, rule=lambda model3, f, a, t: sum(model3.v[(i, a, t)] for i in model3.A_f[f]))
  

# Constraints 
# 1. Cutting constraints - same as Q1
model3.cutting_cnstr = pe.ConstraintList()
for f in model3.F:
    for t in model3.T:
        for l in model3.L:
            for n in possible_longbars[l][f]:
                expression = sum(model3.x[r, l, n, f, t] * w_r[r] for r in model3.R) <= model3.y[l, n, f, t] * w_l[l]
                model3.cutting_cnstr.add(expression)

# 2. Production capacity - same as Q1
model3.capacity_cnstr = pe.ConstraintList()
for f in model3.F:
    for t in model3.T:
        expression = sum(model3.y[l, n, f, t] * w_l[l] for n in possible_longbars[l][f] for l in model3.L) * density * area <= production_capacity[f]
        model3.capacity_cnstr.add(expression)

# Factory output - same as Q2
model3.factory_output = pe.ConstraintList()
for f in model3.F:
    for r in model3.R:
        for t in model3.T:
            expression = sum(model3.q[(r, f, a, t)] for a in model3.A) == sum(model3.x[(r, l, n, f, t)] for n in possible_longbars[l][f] for l in model3.L)
            model3.factory_output.add(expression)

# Link z to q - same as Q2
model3.enforce_factory_usage = pe.ConstraintList()
for f in model3.F:
    for a in model3.A:
        for t in model3.T:
            expression = sum(model3.q[(r, f, a, t)] for r in model3.R) <= M * model3.z[f, a, t]
            model3.enforce_factory_usage.add(expression)
            
#  production triggers customer assignment constraint (link y to z) - same as Q1
model3.prod_triggers_customer_assignment = pe.ConstraintList()
for f in model3.F:
    for t in model3.T:
        # Sum over all r, l, n as specified
        expression = sum(model3.y[ l, n, f, t]
                         for l in model3.L 
                         for n in possible_longbars[l][f]) <= M * sum(model3.z[f, a, t] for a in model3.A)
        
        # Add the constraint to the model
        model3.prod_triggers_customer_assignment.add(expression)


# Demand - same as Q2
model3.demand = pe.ConstraintList()
for a in model3.A:
    for r in model3.R:
        for t in model3.T:
            shipped = sum(model3.q[(r, f, a, t)] for f in model3.F) 
            if t == 1:
                expression = shipped - model3.i[(a,r,t)] == demand[r][a][t-1] 
                model3.demand.add(expression)
            else:
                expression = shipped - model3.i[(a,r,t)] + model3.i[(a,r,t-1)] == demand[r][a][t-1] 
                model3.demand.add(expression)

# Single sourcing - factory assignment - same as Q2
model3.single_sourcing_cnstr = pe.ConstraintList()
for a in model3.A:
    for t in model3.T:
        expression = sum(model3.z[(f,a,t)] for f in model3.F) <= 1
        model3.single_sourcing_cnstr.add(expression)

# Inventory - same as Q2
model3.inventory = pe.ConstraintList()
for a in model3.A:
    for t in model3.T:
        expression = sum(model3.i[(a,r,t)]* w_r[r] for r in model3.R) * density * area <= inventory_capacity[a]
        model3.inventory.add(expression)

# New constraints
                              
# Flow conservation
model3.flow_conservation = pe.ConstraintList()
for j in model3.F_A:
    for t in model3.T:
        expression = sum(model3.v[(i,j,t)] for i in model3.F_A) == sum(model3.v[(j,h,t)] for h in model3.F_A)
        model3.flow_conservation.add(expression)

# Subtour Elimination Constraint
model3.subtour_elimination = pe.ConstraintList()
for f in model3.F:
    for t in model3.T:
        for i in model3.A: 
            for j in model3.A:
                if i != j:
                    expression = model3.u[i,f,t] + model3.t[f,j,t] <= model3.u[j,f,t] + Q * (1 - model3.v[(i, j, t)])
                    model3.subtour_elimination.add(expression)

# Limiting t
model3.upper_bound_t = pe.ConstraintList()
for f in model3.F:
    for t in model3.T:
        for i in model3.A:
            expression = model3.t[f,i,t] <= model3.u[i,f,t]
            model3.upper_bound_t.add(expression)

# don't go from i to i
model3.prevent_loops = pe.ConstraintList()
for t in model3.T:
    for i in model3.F_A:
        expression = model3.v[(i, i, t)] == 0
        model3.prevent_loops.add(expression)


# Limiting u
model3.upper_bound_u = pe.ConstraintList()
for f in model3.F:
    for t in model3.T:
        for i in model3.A:
            expression = model3.u[i,f,t] <= Q
            model3.upper_bound_u.add(expression)

# Vehicle capacity
model3.vehicle_capacity = pe.ConstraintList()
for f in model3.F:
    for t in model3.T:
        expression = sum(model3.t[f,a,t] for a in model3.A) <= Q
        model3.vehicle_capacity.add(expression)


# don't go from one factory to another
model3.disconnect_factories = pe.ConstraintList()
for f in model3.F:
    for t in model3.T:
        expression = sum(model3.v[f,n,t] for n in model3.F) == 0
        model3.disconnect_factories.add(expression)

# ensure if theres shipment, v is positive
model3.ensure_shipment = pe.ConstraintList()
for a in model3.A:
    for t in model3.T:
        expression = sum(model3.t[(f, a, t)] for f in model3.F) <= M* sum(model3.v[i,a,t] for i in model3.F_A) 
        model3.ensure_shipment.add(expression)

# ensure if x>0, v is positive
model3.link_x_v = pe.ConstraintList()
for a in model3.A:
    for t in model3.T:
        expression = sum(model3.x[r, l, n, f, t] for f in model3.F for l in model3.L for r in model3.R for n in possible_longbars[l][f] ) <= M* sum(model3.v[i,a,t] for i in model3.F_A) 
        model3.link_x_v.add(expression)

# ensure if y>0, v is positive
model3.link_y_v = pe.ConstraintList()
for a in model3.A:
    for t in model3.T:
        expression = sum(model3.y[ l, n, f, t] for f in model3.F for l in model3.L for n in possible_longbars[l][f] ) <= M* sum(model3.v[i,a,t] for i in model3.F_A) 
        model3.link_y_v.add(expression)

# leave factory at most once
model3.leave_f_once = pe.ConstraintList()
for j in model3.F_A:
    for t in model3.T:
        expression = sum(model3.v[i,j,t] for i in model3.F_A ) <= 1
        model3.leave_f_once.add(expression)


# Objective function
objExpr = sum( C * sum(model3.v[(i, j, t)] * distanceq3.get(i, {}).get(j, 0) for i in model3.F_A) for j in model3.F_A for t in model3.T)
model3.obj = pe.Objective(expr=objExpr, sense=pe.minimize)

# Solve the model
solver = pe.SolverFactory('gurobi')
result3 = solver.solve(model3, tee=True, options={'TimeLimit':360})

print(f"\nSolver Status: {result3.solver.status}")
print(f"Termination Condition: {result3.solver.termination_condition}")
print(f"Objective value (Total Cost): {pe.value(model3.obj):.2f} €")

#debugging
for f in model3.F:
    for a in model3.A:
        for t in model3.T:
            for r in model3.R:
                if pe.value(model3.q[r, f, a, t]) > 0:
                    print(f"Rebar {r} is shipped from {f} to {a} in period {t} with quantity {pe.value(model3.q[r, f, a, t])}")

for f in model3.F:
    for a in model3.A:
        for t in model3.T:
            if pe.value(model3.z[f, a, t]) > 0:
                print(f"Factory {f} is assigned to customer {a} in period {t}")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2618603
# Academic license - for non-commercial use only - expires 2026-02-05
# Read LP format model from file /var/folders/dh/_xb_27wd2qg4j5p7s0bnfz1w0000gn/T/tmpy13gkxt1.pyomo.lp
# Reading time = 0.09 seconds
# x1: 3384 rows, 8868 columns, 87916 nonzeros
# Set parameter TimeLimit to value 360
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[x86] - Darwin 23.6.0 23H417)
#
# CPU model: Intel(R) Core(TM) i5-8210Y CPU @ 1.60GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Non-default parameters:
# TimeLimit  360
#
# Optimize a model with 3384 rows, 8868 columns and 87916 nonzeros
# Model fingerprint: 0x84a5ad4e
# Variable types: 0 continuous, 8868 integer (2532 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 3e+02]
#   Objective range  [4e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]

# %%
# Print all values of v (binary decision variable)
for t in model3.T:
    for i in model3.F_A:
        for j in model3.F_A:
        
            v_value = pe.value(model3.v[( i, j, t)])
            if v_value > 0:
                print(f"v[ {i}, {j}, {t}] = {v_value}")
# Out:
# v[ Segal, Neuss, 1] = 1.0
# v[ Bochum, Dortmund, 1] = 1.0
# v[ Boenen, Segal, 1] = 1.0
# v[ Dortmund, Hagen, 1] = 1.0
# v[ Gelsenkirchen, Bochum, 1] = 1.0
# v[ Hagen, Iserlohn, 1] = 1.0
# v[ Iserlohn, Schwerte, 1] = 1.0
# v[ Neuss, Gelsenkirchen, 1] = 1.0
# v[ Schwerte, Boenen, 1] = 1.0
# v[ IJmuiden, Bochum, 2] = 1.0
# v[ Segal, Bochum, 2] = 1.0
# v[ South Wales, Bochum, 2] = 1.0
# v[ Bochum, Dortmund, 2] = 1.0
# v[ Bochum, Gelsenkirchen, 2] = 1.0
# v[ Bochum, Neuss, 2] = 1.0
# v[ Boenen, Segal, 2] = 1.0
# v[ Boenen, South Wales, 2] = 1.0
# v[ Dortmund, Schwerte, 2] = 1.0
# v[ Gelsenkirchen, Boenen, 2] = 1.0
# v[ Hagen, Iserlohn, 2] = 1.0
# v[ Iserlohn, Boenen, 2] = 1.0
# v[ Neuss, IJmuiden, 2] = 1.0
# v[ Schwerte, Hagen, 2] = 1.0
# v[ IJmuiden, Schwerte, 3] = 1.0
# v[ Segal, Dortmund, 3] = 1.0
# v[ South Wales, Gelsenkirchen, 3] = 1.0
# v[ Bochum, Neuss, 3] = 1.0
# v[ Boenen, IJmuiden, 3] = 1.0
# v[ Dortmund, Boenen, 3] = 1.0
# v[ Gelsenkirchen, Bochum, 3] = 1.0
# v[ Hagen, Segal, 3] = 1.0
# v[ Iserlohn, South Wales, 3] = 1.0
# v[ Neuss, Schwerte, 3] = 1.0
# v[ Schwerte, Hagen, 3] = 1.0
# v[ Schwerte, Iserlohn, 3] = 1.0
# v[ IJmuiden, Bochum, 4] = 1.0
# v[ Segal, Bochum, 4] = 1.0
# v[ South Wales, Bochum, 4] = 1.0
# v[ Bochum, Gelsenkirchen, 4] = 1.0
# v[ Bochum, Neuss, 4] = 1.0
# v[ Bochum, Schwerte, 4] = 1.0
# v[ Boenen, South Wales, 4] = 1.0
# v[ Dortmund, Boenen, 4] = 1.0
# v[ Gelsenkirchen, Schwerte, 4] = 1.0
# v[ Hagen, IJmuiden, 4] = 1.0
# v[ Iserlohn, Segal, 4] = 1.0
# v[ Neuss, Schwerte, 4] = 1.0
# v[ Schwerte, Dortmund, 4] = 1.0
# v[ Schwerte, Hagen, 4] = 1.0
# v[ Schwerte, Iserlohn, 4] = 1.0

# %%
for t in model3.T:
    for f in model3.F:
        print(f"\nFactory {f} - Period {t}:")
        visited_customers = []

        # Identify the customers visited by this factory in period t
        for i in model3.A_f[f]:
            if pe.value(model3.v[(f, i, t)]) > 0.5:
                next_customer = i
                visited_customers.append(i)
                visited_set = {i}  # To track visited nodes

                while next_customer != f:
                    found_next = False  # Flag to check if we find a next customer

                    for j in model3.A_f[f]:
                        if (
                            i != j 
                            and pe.value(model3.v[next_customer, j, t]) > 0.5  # Safe access
                            and j not in visited_set  # Prevent cycling
                        ):
                            next_customer = j
                            visited_customers.append(next_customer)
                            visited_set.add(next_customer)
                            found_next = True
                            break  # Move to next customer

                    if not found_next:
                        break  # Stop if no valid next customer is found

        # Print the route
        if visited_customers:
            route_str = f"Start -> " + " -> ".join(map(str, visited_customers)) + " -> End"
            print(route_str)
        else:
            print("No route assigned (no customers visited).")
# Out:
# Factory IJmuiden - Period 1:
# No route assigned (no customers visited).
#
# Factory Segal - Period 1:
# Start -> Neuss -> Gelsenkirchen -> Bochum -> Dortmund -> Boenen -> Schwerte -> Iserlohn -> Hagen -> Segal -> End
#
# Factory South Wales - Period 1:
# No route assigned (no customers visited).
#
# Factory IJmuiden - Period 2:
# Start -> Dortmund -> Schwerte -> Hagen -> Iserlohn -> Boenen -> IJmuiden -> End
#
# Factory Segal - Period 2:
# Start -> Bochum -> Gelsenkirchen -> Neuss -> Segal -> End
#
# Factory South Wales - Period 2:
# No route assigned (no customers visited).
#
# Factory IJmuiden - Period 3:
# Start -> Gelsenkirchen -> Bochum -> Neuss -> End
#
# Factory Segal - Period 3:
# No route assigned (no customers visited).
#
# Factory South Wales - Period 3:
# Start -> Schwerte -> Iserlohn -> Hagen -> Dortmund -> Boenen -> End
#
# Factory IJmuiden - Period 4:
# Start -> Bochum -> Neuss -> Gelsenkirchen -> IJmuiden -> End
#
# Factory Segal - Period 4:
# Start -> Schwerte -> Iserlohn -> Hagen -> Dortmund -> Boenen -> Segal -> End
#
# Factory South Wales - Period 4:
# No route assigned (no customers visited).

# %%
# Analysis of production and demand

total_demand_per_period = {1: 0, 2: 0, 3: 0, 4: 0}
for r in rebars:
    for customer in demand[r]:
        for t in range(4):  # For each period
            # Demand in tonnes for each rebar type, customer, and period
            demand_in_tonnes = demand[r][customer][t] * w_r[r] * density * area
            total_demand_per_period[t + 1] += demand_in_tonnes

# Initialize a dictionary to store production data
factory_production = {f: {t: 0 for t in range(1, 5)} for f in ["IJmuiden", "Segal", "South Wales"]}
total_production_per_period = {t: 0 for t in range(1, 5)}  # Total production for each period

# Extract production values from model3
for f in factory_production:
    for t in factory_production[f]:
        total_tonnes = sum(
            pe.value(model3.y[l, n, f, t]) * w_l[l] * density * area
            for l in model3.L for n in possible_longbars[l][f]
            if pe.value(model3.y[l, n, f, t]) > 0.5
        )
        factory_production[f][t] = round(total_tonnes, 2)  # Round to 2 decimals
        total_production_per_period[t] += total_tonnes  # Update total production per period

# Print table
print("Factory Production (Tonnes per Period)")
print("-" * 80)
print(f"{'Factory':<15} {'P1':<10} {'P2':<10} {'P3':<10} {'P4':<10} ")
print("-" * 80)

# Print the factory production values
for f, periods in factory_production.items():
    row = f"{f:<15}"
    for t in range(1, 5):
        row += f"{periods[t]:<10}"
    print(row)

# Print total production across all factories
row = f"{'Total Production':<15}"
for t in range(1, 5):
    row += f"{total_production_per_period[t]:<10}"
row += f"{round(sum(total_production_per_period.values()), 2):<15.2f}"  # Rounded total production
print(row)

# Print total demand per period
row = f"{'Total Demand':<15}"
for t in total_demand_per_period:
    row += f"{round(total_demand_per_period[t], 2):<10}"
print(row)

print()

# Cost per period

total_cost_per_period = {t: 0 for t in model3.T}  # Dictionary to store total cost for each period

# Loop through each period, customer, and factory to calculate the total cost per period
for t in model3.T:
    period_cost = 0  # Initialize the cost for the current period
    for f in model3.F:
        for a in model3.A:
            # Calculate the cost of transportation and fixed costs for each factory, customer, and period
            
            period_cost += pe.value(model3.z[f, a, t]) * (
            C * (sum(pe.value(model3.v[(i, a, t)]) * distanceq3.get(i, {}).get(a, 0) for i in model3.A_f[f]) + pe.value(model3.v[(a, f, t)]) * distanceq3.get(a, {}).get(f, 0) )
            )
    # Store the total cost for this period
    total_cost_per_period[t] = period_cost

# Print the total cost per period
for t in total_cost_per_period:
    print(f"Total cost for Period {t}: €{total_cost_per_period[t]:.2f}")
# Out:
# Factory Production (Tonnes per Period)
# --------------------------------------------------------------------------------
# Factory         P1         P2         P3         P4
# --------------------------------------------------------------------------------
# IJmuiden       10.52     11.96     11.96     10.22
# Segal          4.81      9.98      9.55      7.75
# South Wales    24.16     26.02     22.96     18.93
# Total Production39.4817026834146947.9549448118187544.46949769517027636.89766430383047168.80
# Total Demand   15.48     23.73     23.06     25.02
#
# Total cost for Period 1: €777.00
# Total cost for Period 2: €1008.00
# Total cost for Period 3: €372.00
# Total cost for Period 4: €303.00

# %%
print("Non-null variable values:")

for var in model3.component_objects(pe.Var, active=True):  # Iterate over all variables
    print(f"\nVariable: {var.name}")
    for index in var:
        value = pe.value(var[index])
        if value is not None and value > 0.5:
            print(f"  {index} = {value}")
# Out:
# Non-null variable values:
#
# Variable: x
#   ('A', 1, 1, 'IJmuiden', 1) = 3.0
#   ('A', 1, 3, 'IJmuiden', 1) = 3.0
#   ('A', 1, 5, 'IJmuiden', 4) = 1.0
#   ('A', 1, 10, 'IJmuiden', 1) = 1.0
#   ('A', 1, 15, 'IJmuiden', 3) = 3.0
#   ('A', 1, 28, 'IJmuiden', 1) = 3.0
#   ('A', 1, 30, 'IJmuiden', 1) = 3.0
#   ('A', 1, 31, 'IJmuiden', 2) = 2.0
#   ('A', 1, 33, 'IJmuiden', 3) = 3.0
#   ('A', 1, 34, 'IJmuiden', 4) = 3.0
#   ('A', 1, 36, 'IJmuiden', 1) = 3.0
#   ('A', 1, 39, 'IJmuiden', 3) = 2.0
#   ('A', 1, 42, 'IJmuiden', 3) = 3.0
#   ('A', 1, 42, 'IJmuiden', 4) = 3.0
#   ('A', 1, 48, 'IJmuiden', 1) = 3.0
#   ('A', 1, 6, 'Segal', 2) = 1.0
#   ('A', 1, 17, 'Segal', 1) = 3.0
#   ('A', 1, 18, 'Segal', 3) = 3.0
#   ('A', 1, 20, 'Segal', 2) = 3.0
#   ('A', 1, 24, 'Segal', 4) = 2.0
#   ('A', 1, 33, 'Segal', 3) = 3.0
#   ('A', 1, 34, 'Segal', 1) = 3.0
#   ('A', 1, 38, 'Segal', 2) = 3.0
#   ('A', 1, 39, 'Segal', 2) = 2.0
#   ('A', 1, 39, 'Segal', 4) = 3.0
#   ('A', 1, 2, 'South Wales', 1) = 3.0
#   ('A', 1, 4, 'South Wales', 3) = 1.0
#   ('A', 1, 9, 'South Wales', 1) = 3.0
#   ('A', 1, 9, 'South Wales', 2) = 3.0
#   ('A', 1, 17, 'South Wales', 2) = 3.0
#   ('A', 1, 19, 'South Wales', 2) = 3.0
#   ('A', 1, 30, 'South Wales', 2) = 3.0
#   ('A', 1, 32, 'South Wales', 2) = 3.0
#   ('A', 1, 50, 'South Wales', 2) = 3.0
#   ('A', 1, 52, 'South Wales', 2) = 3.0
#   ('A', 1, 56, 'South Wales', 4) = 3.0
#   ('A', 1, 57, 'South Wales', 4) = 3.0
#   ('A', 1, 64, 'South Wales', 2) = 3.0
#   ('A', 1, 74, 'South Wales', 2) = 3.0
#   ('A', 1, 90, 'South Wales', 2) = 3.0
#   ('A', 1, 93, 'South Wales', 1) = 3.0
#   ('A', 1, 93, 'South Wales', 3) = 3.0
#   ('A', 1, 106, 'South Wales', 1) = 3.0
#   ('A', 2, 1, 'IJmuiden', 1) = 1.0
#   ('A', 2, 1, 'IJmuiden', 4) = 1.0
#   ('A', 2, 4, 'IJmuiden', 1) = 1.0
#   ('A', 2, 4, 'IJmuiden', 3) = 5.0
#   ('A', 2, 5, 'IJmuiden', 2) = 5.0
#   ('A', 2, 6, 'IJmuiden', 4) = 5.0
#   ('A', 2, 11, 'IJmuiden', 1) = 3.0
#   ('A', 2, 15, 'IJmuiden', 1) = 5.0
#   ('A', 2, 16, 'IJmuiden', 2) = 3.0
#   ('A', 2, 16, 'IJmuiden', 4) = 1.0
#   ('A', 2, 17, 'IJmuiden', 3) = 5.0
#   ('A', 2, 22, 'IJmuiden', 1) = 1.0
#   ('A', 2, 24, 'IJmuiden', 3) = 1.0
#   ('A', 2, 25, 'IJmuiden', 3) = 5.0
#   ('A', 2, 26, 'IJmuiden', 4) = 5.0
#   ('A', 2, 30, 'IJmuiden', 1) = 1.0
#   ('A', 2, 32, 'IJmuiden', 3) = 1.0
#   ('A', 2, 37, 'IJmuiden', 1) = 3.0
#   ('A', 2, 39, 'IJmuiden', 3) = 5.0
#   ('A', 2, 44, 'IJmuiden', 3) = 1.0
#   ('A', 2, 45, 'IJmuiden', 3) = 5.0
#   ('A', 2, 48, 'IJmuiden', 1) = 1.0
#   ('A', 2, 49, 'IJmuiden', 1) = 1.0
#   ('A', 2, 50, 'IJmuiden', 1) = 1.0
#   ('A', 2, 5, 'Segal', 3) = 5.0
#   ('A', 2, 13, 'Segal', 3) = 5.0
#   ('A', 2, 14, 'Segal', 3) = 5.0
#   ('A', 2, 27, 'Segal', 1) = 5.0
#   ('A', 2, 28, 'Segal', 2) = 2.0
#   ('A', 2, 29, 'Segal', 2) = 1.0
#   ('A', 2, 29, 'Segal', 3) = 1.0
#   ('A', 2, 33, 'Segal', 4) = 5.0
#   ('A', 2, 35, 'Segal', 2) = 3.0
#   ('A', 2, 37, 'Segal', 2) = 1.0
#   ('A', 2, 38, 'Segal', 1) = 2.0
#   ('A', 2, 42, 'Segal', 4) = 5.0
#   ('A', 2, 9, 'South Wales', 4) = 4.0
#   ('A', 2, 11, 'South Wales', 4) = 1.0
#   ('A', 2, 17, 'South Wales', 2) = 1.0
#   ('A', 2, 19, 'South Wales', 2) = 1.0
#   ('A', 2, 22, 'South Wales', 3) = 3.0
#   ('A', 2, 24, 'South Wales', 1) = 5.0
#   ('A', 2, 27, 'South Wales', 4) = 5.0
#   ('A', 2, 28, 'South Wales', 3) = 1.0
#   ('A', 2, 30, 'South Wales', 1) = 5.0
#   ('A', 2, 33, 'South Wales', 3) = 5.0
#   ('A', 2, 37, 'South Wales', 3) = 5.0
#   ('A', 2, 43, 'South Wales', 3) = 1.0
#   ('A', 2, 46, 'South Wales', 2) = 1.0
#   ('A', 2, 51, 'South Wales', 1) = 5.0
#   ('A', 2, 59, 'South Wales', 2) = 4.0
#   ('A', 2, 62, 'South Wales', 2) = 5.0
#   ('A', 2, 64, 'South Wales', 1) = 3.0
#   ('A', 2, 64, 'South Wales', 3) = 1.0
#   ('A', 2, 66, 'South Wales', 1) = 5.0
#   ('A', 2, 78, 'South Wales', 4) = 5.0
#   ('A', 2, 79, 'South Wales', 4) = 2.0
#   ('A', 2, 85, 'South Wales', 1) = 1.0
#   ('A', 2, 86, 'South Wales', 4) = 5.0
#   ('A', 2, 90, 'South Wales', 2) = 1.0
#   ('A', 2, 93, 'South Wales', 2) = 5.0
#   ('A', 2, 98, 'South Wales', 2) = 1.0
#   ('A', 2, 101, 'South Wales', 3) = 1.0
#   ('A', 2, 107, 'South Wales', 2) = 5.0
#   ('A', 2, 111, 'South Wales', 1) = 5.0
#   ('A', 2, 113, 'South Wales', 3) = 1.0
#   ('A', 2, 116, 'South Wales', 1) = 5.0
#   ('B', 1, 1, 'IJmuiden', 2) = 2.0
#   ('B', 1, 2, 'IJmuiden', 1) = 2.0
#   ('B', 1, 3, 'IJmuiden', 3) = 2.0
#   ('B', 1, 5, 'IJmuiden', 4) = 1.0
#   ('B', 1, 8, 'IJmuiden', 1) = 2.0
#   ('B', 1, 9, 'IJmuiden', 1) = 2.0
#   ('B', 1, 9, 'IJmuiden', 4) = 2.0
#   ('B', 1, 11, 'IJmuiden', 4) = 2.0
#   ('B', 1, 13, 'IJmuiden', 2) = 2.0
#   ('B', 1, 15, 'IJmuiden', 1) = 2.0
#   ('B', 1, 20, 'IJmuiden', 2) = 2.0
#   ('B', 1, 21, 'IJmuiden', 1) = 2.0
#   ('B', 1, 21, 'IJmuiden', 4) = 2.0
#   ('B', 1, 24, 'IJmuiden', 1) = 2.0
#   ('B', 1, 24, 'IJmuiden', 3) = 2.0
#   ('B', 1, 30, 'IJmuiden', 4) = 2.0
#   ('B', 1, 32, 'IJmuiden', 3) = 2.0
#   ('B', 1, 33, 'IJmuiden', 4) = 1.0
#   ('B', 1, 39, 'IJmuiden', 3) = 1.0
#   ('B', 1, 39, 'IJmuiden', 4) = 2.0
#   ('B', 1, 41, 'IJmuiden', 1) = 1.0
#   ('B', 1, 41, 'IJmuiden', 4) = 2.0
#   ('B', 1, 47, 'IJmuiden', 3) = 2.0
#   ('B', 1, 48, 'IJmuiden', 3) = 2.0
#   ('B', 1, 48, 'IJmuiden', 4) = 1.0
#   ('B', 1, 50, 'IJmuiden', 4) = 2.0
#   ('B', 1, 1, 'Segal', 2) = 2.0
#   ('B', 1, 1, 'Segal', 4) = 2.0
#   ('B', 1, 3, 'Segal', 1) = 2.0
#   ('B', 1, 3, 'Segal', 2) = 2.0
#   ('B', 1, 3, 'Segal', 3) = 2.0
#   ('B', 1, 3, 'Segal', 4) = 1.0
#   ('B', 1, 4, 'Segal', 1) = 2.0
#   ('B', 1, 5, 'Segal', 4) = 2.0
#   ('B', 1, 6, 'Segal', 1) = 2.0
#   ('B', 1, 8, 'Segal', 3) = 2.0
#   ('B', 1, 11, 'Segal', 3) = 2.0
#   ('B', 1, 11, 'Segal', 4) = 2.0
#   ('B', 1, 18, 'Segal', 2) = 2.0
#   ('B', 1, 21, 'Segal', 2) = 2.0
#   ('B', 1, 25, 'Segal', 3) = 2.0
#   ('B', 1, 26, 'Segal', 2) = 2.0
#   ('B', 1, 27, 'Segal', 1) = 2.0
#   ('B', 1, 29, 'Segal', 1) = 2.0
#   ('B', 1, 38, 'Segal', 4) = 2.0
#   ('B', 1, 39, 'Segal', 2) = 1.0
#   ('B', 1, 40, 'Segal', 1) = 2.0
#   ('B', 1, 1, 'South Wales', 1) = 2.0
#   ('B', 1, 3, 'South Wales', 2) = 2.0
#   ('B', 1, 4, 'South Wales', 1) = 2.0
#   ('B', 1, 4, 'South Wales', 2) = 1.0
#   ('B', 1, 10, 'South Wales', 4) = 2.0
#   ('B', 1, 13, 'South Wales', 1) = 2.0
#   ('B', 1, 13, 'South Wales', 3) = 2.0
#   ('B', 1, 13, 'South Wales', 4) = 2.0
#   ('B', 1, 14, 'South Wales', 1) = 2.0
#   ('B', 1, 15, 'South Wales', 4) = 2.0
#   ('B', 1, 16, 'South Wales', 4) = 2.0
#   ('B', 1, 17, 'South Wales', 3) = 2.0
#   ('B', 1, 22, 'South Wales', 4) = 2.0
#   ('B', 1, 23, 'South Wales', 1) = 2.0
#   ('B', 1, 33, 'South Wales', 1) = 2.0
#   ('B', 1, 35, 'South Wales', 2) = 2.0
#   ('B', 1, 37, 'South Wales', 2) = 2.0
#   ('B', 1, 41, 'South Wales', 2) = 2.0
#   ('B', 1, 44, 'South Wales', 2) = 2.0
#   ('B', 1, 46, 'South Wales', 2) = 2.0
#   ('B', 1, 47, 'South Wales', 2) = 2.0
#   ('B', 1, 50, 'South Wales', 1) = 2.0
#   ('B', 1, 51, 'South Wales', 2) = 1.0
#   ('B', 1, 52, 'South Wales', 3) = 2.0
#   ('B', 1, 56, 'South Wales', 1) = 2.0
#   ('B', 1, 60, 'South Wales', 1) = 2.0
#   ('B', 1, 62, 'South Wales', 1) = 2.0
#   ('B', 1, 62, 'South Wales', 2) = 2.0
#   ('B', 1, 67, 'South Wales', 4) = 2.0
#   ('B', 1, 71, 'South Wales', 1) = 2.0
#   ('B', 1, 72, 'South Wales', 3) = 2.0
#   ('B', 1, 77, 'South Wales', 3) = 2.0
#   ('B', 1, 78, 'South Wales', 1) = 1.0
#   ('B', 1, 78, 'South Wales', 2) = 2.0
#   ('B', 1, 79, 'South Wales', 4) = 1.0
#   ('B', 1, 86, 'South Wales', 4) = 2.0
#   ('B', 1, 90, 'South Wales', 3) = 2.0
#   ('B', 1, 90, 'South Wales', 4) = 2.0
#   ('B', 1, 91, 'South Wales', 2) = 2.0
#   ('B', 1, 91, 'South Wales', 3) = 2.0
#   ('B', 1, 96, 'South Wales', 1) = 2.0
#   ('B', 1, 97, 'South Wales', 3) = 2.0
#   ('B', 1, 98, 'South Wales', 2) = 2.0
#   ('B', 1, 99, 'South Wales', 3) = 2.0
#   ('B', 1, 100, 'South Wales', 2) = 2.0
#   ('B', 1, 103, 'South Wales', 4) = 2.0
#   ('B', 1, 109, 'South Wales', 1) = 2.0
#   ('B', 1, 111, 'South Wales', 2) = 2.0
#   ('B', 1, 117, 'South Wales', 3) = 2.0
#   ('B', 2, 1, 'IJmuiden', 1) = 2.0
#   ('B', 2, 9, 'IJmuiden', 2) = 3.0
#   ('B', 2, 10, 'IJmuiden', 4) = 1.0
#   ('B', 2, 11, 'IJmuiden', 1) = 1.0
#   ('B', 2, 13, 'IJmuiden', 2) = 3.0
#   ('B', 2, 16, 'IJmuiden', 3) = 1.0
#   ('B', 2, 18, 'IJmuiden', 3) = 3.0
#   ('B', 2, 19, 'IJmuiden', 4) = 3.0
#   ('B', 2, 21, 'IJmuiden', 4) = 3.0
#   ('B', 2, 22, 'IJmuiden', 1) = 2.0
#   ('B', 2, 22, 'IJmuiden', 3) = 1.0
#   ('B', 2, 23, 'IJmuiden', 1) = 1.0
#   ('B', 2, 23, 'IJmuiden', 3) = 3.0
#   ('B', 2, 24, 'IJmuiden', 3) = 1.0
#   ('B', 2, 25, 'IJmuiden', 1) = 2.0
#   ('B', 2, 27, 'IJmuiden', 3) = 3.0
#   ('B', 2, 28, 'IJmuiden', 1) = 3.0
#   ('B', 2, 28, 'IJmuiden', 4) = 3.0
#   ('B', 2, 29, 'IJmuiden', 3) = 1.0
#   ('B', 2, 30, 'IJmuiden', 3) = 1.0
#   ('B', 2, 30, 'IJmuiden', 4) = 3.0
#   ('B', 2, 32, 'IJmuiden', 1) = 1.0
#   ('B', 2, 33, 'IJmuiden', 1) = 1.0
#   ('B', 2, 33, 'IJmuiden', 4) = 3.0
#   ('B', 2, 36, 'IJmuiden', 4) = 3.0
#   ('B', 2, 37, 'IJmuiden', 3) = 3.0
#   ('B', 2, 38, 'IJmuiden', 2) = 3.0
#   ('B', 2, 39, 'IJmuiden', 2) = 1.0
#   ('B', 2, 41, 'IJmuiden', 3) = 3.0
#   ('B', 2, 42, 'IJmuiden', 4) = 1.0
#   ('B', 2, 43, 'IJmuiden', 1) = 2.0
#   ('B', 2, 45, 'IJmuiden', 1) = 1.0
#   ('B', 2, 46, 'IJmuiden', 1) = 3.0
#   ('B', 2, 1, 'Segal', 3) = 1.0
#   ('B', 2, 2, 'Segal', 3) = 3.0
#   ('B', 2, 2, 'Segal', 4) = 3.0
#   ('B', 2, 3, 'Segal', 1) = 3.0
#   ('B', 2, 5, 'Segal', 2) = 2.0
#   ('B', 2, 6, 'Segal', 3) = 1.0
#   ('B', 2, 7, 'Segal', 1) = 3.0
#   ('B', 2, 7, 'Segal', 3) = 3.0
#   ('B', 2, 12, 'Segal', 3) = 1.0
#   ('B', 2, 15, 'Segal', 3) = 1.0
#   ('B', 2, 21, 'Segal', 2) = 2.0
#   ('B', 2, 21, 'Segal', 4) = 3.0
#   ('B', 2, 22, 'Segal', 2) = 1.0
#   ('B', 2, 25, 'Segal', 4) = 1.0
#   ('B', 2, 26, 'Segal', 4) = 3.0
#   ('B', 2, 27, 'Segal', 2) = 1.0
#   ('B', 2, 28, 'Segal', 2) = 2.0
#   ('B', 2, 30, 'Segal', 3) = 3.0
#   ('B', 2, 33, 'Segal', 1) = 2.0
#   ('B', 2, 33, 'Segal', 3) = 3.0
#   ('B', 2, 34, 'Segal', 2) = 1.0
#   ('B', 2, 34, 'Segal', 3) = 3.0
#   ('B', 2, 35, 'Segal', 3) = 3.0
#   ('B', 2, 36, 'Segal', 2) = 2.0
#   ('B', 2, 37, 'Segal', 3) = 1.0
#   ('B', 2, 38, 'Segal', 1) = 2.0
#   ('B', 2, 39, 'Segal', 2) = 1.0
#   ('B', 2, 40, 'Segal', 1) = 3.0
#   ('B', 2, 1, 'South Wales', 1) = 1.0
#   ('B', 2, 1, 'South Wales', 4) = 3.0
#   ('B', 2, 2, 'South Wales', 2) = 3.0
#   ('B', 2, 5, 'South Wales', 4) = 1.0
#   ('B', 2, 10, 'South Wales', 4) = 3.0
#   ('B', 2, 12, 'South Wales', 4) = 1.0
#   ('B', 2, 13, 'South Wales', 2) = 3.0
#   ('B', 2, 13, 'South Wales', 3) = 3.0
#   ('B', 2, 13, 'South Wales', 4) = 3.0
#   ('B', 2, 14, 'South Wales', 1) = 3.0
#   ('B', 2, 15, 'South Wales', 2) = 1.0
#   ('B', 2, 18, 'South Wales', 2) = 1.0
#   ('B', 2, 22, 'South Wales', 2) = 3.0
#   ('B', 2, 26, 'South Wales', 1) = 3.0
#   ('B', 2, 26, 'South Wales', 2) = 1.0
#   ('B', 2, 27, 'South Wales', 1) = 3.0
#   ('B', 2, 29, 'South Wales', 3) = 3.0
#   ('B', 2, 30, 'South Wales', 2) = 1.0
#   ('B', 2, 30, 'South Wales', 4) = 3.0
#   ('B', 2, 34, 'South Wales', 3) = 1.0
#   ('B', 2, 34, 'South Wales', 4) = 3.0
#   ('B', 2, 41, 'South Wales', 2) = 3.0
#   ('B', 2, 42, 'South Wales', 3) = 3.0
#   ('B', 2, 49, 'South Wales', 3) = 3.0
#   ('B', 2, 50, 'South Wales', 2) = 3.0
#   ('B', 2, 53, 'South Wales', 4) = 3.0
#   ('B', 2, 54, 'South Wales', 2) = 1.0
#   ('B', 2, 58, 'South Wales', 4) = 3.0
#   ('B', 2, 59, 'South Wales', 1) = 3.0
#   ('B', 2, 60, 'South Wales', 1) = 1.0
#   ('B', 2, 65, 'South Wales', 1) = 3.0
#   ('B', 2, 65, 'South Wales', 2) = 3.0
#   ('B', 2, 66, 'South Wales', 3) = 3.0
#   ('B', 2, 70, 'South Wales', 2) = 3.0
#   ('B', 2, 72, 'South Wales', 4) = 3.0
#   ('B', 2, 73, 'South Wales', 2) = 3.0
#   ('B', 2, 74, 'South Wales', 4) = 3.0
#   ('B', 2, 79, 'South Wales', 4) = 2.0
#   ('B', 2, 84, 'South Wales', 4) = 3.0
#   ('B', 2, 85, 'South Wales', 3) = 3.0
#   ('B', 2, 90, 'South Wales', 1) = 1.0
#   ('B', 2, 94, 'South Wales', 2) = 3.0
#   ('B', 2, 96, 'South Wales', 4) = 3.0
#   ('B', 2, 97, 'South Wales', 2) = 3.0
#   ('B', 2, 97, 'South Wales', 4) = 1.0
#   ('B', 2, 100, 'South Wales', 4) = 3.0
#   ('B', 2, 101, 'South Wales', 2) = 3.0
#   ('B', 2, 104, 'South Wales', 3) = 3.0
#   ('B', 2, 107, 'South Wales', 3) = 3.0
#   ('B', 2, 107, 'South Wales', 4) = 3.0
#   ('B', 2, 109, 'South Wales', 2) = 3.0
#   ('B', 2, 110, 'South Wales', 1) = 3.0
#   ('B', 2, 112, 'South Wales', 1) = 1.0
#   ('C', 1, 1, 'IJmuiden', 3) = 2.0
#   ('C', 1, 1, 'IJmuiden', 4) = 2.0
#   ('C', 1, 2, 'IJmuiden', 2) = 2.0
#   ('C', 1, 4, 'IJmuiden', 1) = 2.0
#   ('C', 1, 5, 'IJmuiden', 1) = 2.0
#   ('C', 1, 5, 'IJmuiden', 3) = 2.0
#   ('C', 1, 8, 'IJmuiden', 4) = 2.0
#   ('C', 1, 10, 'IJmuiden', 1) = 1.0
#   ('C', 1, 11, 'IJmuiden', 1) = 2.0
#   ('C', 1, 11, 'IJmuiden', 2) = 2.0
#   ('C', 1, 18, 'IJmuiden', 4) = 2.0
#   ('C', 1, 19, 'IJmuiden', 1) = 2.0
#   ('C', 1, 20, 'IJmuiden', 3) = 2.0
#   ('C', 1, 20, 'IJmuiden', 4) = 2.0
#   ('C', 1, 21, 'IJmuiden', 2) = 2.0
#   ('C', 1, 24, 'IJmuiden', 4) = 2.0
#   ('C', 1, 26, 'IJmuiden', 1) = 2.0
#   ('C', 1, 26, 'IJmuiden', 3) = 2.0
#   ('C', 1, 29, 'IJmuiden', 1) = 2.0
#   ('C', 1, 30, 'IJmuiden', 3) = 2.0
#   ('C', 1, 31, 'IJmuiden', 1) = 2.0
#   ('C', 1, 32, 'IJmuiden', 1) = 2.0
#   ('C', 1, 32, 'IJmuiden', 4) = 2.0
#   ('C', 1, 33, 'IJmuiden', 4) = 1.0
#   ('C', 1, 34, 'IJmuiden', 1) = 2.0
#   ('C', 1, 39, 'IJmuiden', 1) = 2.0
#   ('C', 1, 40, 'IJmuiden', 3) = 2.0
#   ('C', 1, 41, 'IJmuiden', 1) = 1.0
#   ('C', 1, 46, 'IJmuiden', 1) = 2.0
#   ('C', 1, 46, 'IJmuiden', 3) = 2.0
#   ('C', 1, 47, 'IJmuiden', 1) = 2.0
#   ('C', 1, 50, 'IJmuiden', 1) = 2.0
#   ('C', 1, 2, 'Segal', 4) = 2.0
#   ('C', 1, 5, 'Segal', 3) = 2.0
#   ('C', 1, 7, 'Segal', 3) = 2.0
#   ('C', 1, 7, 'Segal', 4) = 2.0
#   ('C', 1, 8, 'Segal', 1) = 2.0
#   ('C', 1, 9, 'Segal', 3) = 2.0
#   ('C', 1, 9, 'Segal', 4) = 2.0
#   ('C', 1, 13, 'Segal', 4) = 2.0
#   ('C', 1, 15, 'Segal', 3) = 2.0
#   ('C', 1, 15, 'Segal', 4) = 2.0
#   ('C', 1, 17, 'Segal', 2) = 2.0
#   ('C', 1, 19, 'Segal', 3) = 1.0
#   ('C', 1, 19, 'Segal', 4) = 2.0
#   ('C', 1, 23, 'Segal', 1) = 2.0
#   ('C', 1, 27, 'Segal', 3) = 2.0
#   ('C', 1, 35, 'Segal', 2) = 2.0
#   ('C', 1, 37, 'Segal', 1) = 2.0
#   ('C', 1, 37, 'Segal', 3) = 2.0
#   ('C', 1, 40, 'Segal', 3) = 2.0
#   ('C', 1, 40, 'Segal', 4) = 2.0
#   ('C', 1, 41, 'Segal', 1) = 2.0
#   ('C', 1, 41, 'Segal', 3) = 2.0
#   ('C', 1, 41, 'Segal', 4) = 2.0
#   ('C', 1, 3, 'South Wales', 3) = 2.0
#   ('C', 1, 4, 'South Wales', 2) = 1.0
#   ('C', 1, 4, 'South Wales', 3) = 1.0
#   ('C', 1, 4, 'South Wales', 4) = 2.0
#   ('C', 1, 6, 'South Wales', 4) = 2.0
#   ('C', 1, 7, 'South Wales', 2) = 2.0
#   ('C', 1, 8, 'South Wales', 1) = 2.0
#   ('C', 1, 10, 'South Wales', 1) = 2.0
#   ('C', 1, 11, 'South Wales', 3) = 2.0
#   ('C', 1, 14, 'South Wales', 4) = 2.0
#   ('C', 1, 21, 'South Wales', 2) = 2.0
#   ('C', 1, 21, 'South Wales', 3) = 2.0
#   ('C', 1, 22, 'South Wales', 1) = 2.0
#   ('C', 1, 22, 'South Wales', 3) = 2.0
#   ('C', 1, 24, 'South Wales', 3) = 2.0
#   ('C', 1, 25, 'South Wales', 3) = 2.0
#   ('C', 1, 26, 'South Wales', 4) = 2.0
#   ('C', 1, 28, 'South Wales', 3) = 2.0
#   ('C', 1, 29, 'South Wales', 1) = 2.0
#   ('C', 1, 29, 'South Wales', 4) = 2.0
#   ('C', 1, 31, 'South Wales', 2) = 2.0
#   ('C', 1, 32, 'South Wales', 4) = 2.0
#   ('C', 1, 33, 'South Wales', 2) = 2.0
#   ('C', 1, 33, 'South Wales', 4) = 2.0
#   ('C', 1, 40, 'South Wales', 3) = 2.0
#   ('C', 1, 43, 'South Wales', 3) = 2.0
#   ('C', 1, 44, 'South Wales', 1) = 2.0
#   ('C', 1, 46, 'South Wales', 1) = 2.0
#   ('C', 1, 48, 'South Wales', 1) = 2.0
#   ('C', 1, 53, 'South Wales', 2) = 2.0
#   ('C', 1, 55, 'South Wales', 4) = 2.0
#   ('C', 1, 57, 'South Wales', 3) = 2.0
#   ('C', 1, 62, 'South Wales', 3) = 2.0
#   ('C', 1, 66, 'South Wales', 4) = 2.0
#   ('C', 1, 68, 'South Wales', 2) = 2.0
#   ('C', 1, 71, 'South Wales', 3) = 2.0
#   ('C', 1, 72, 'South Wales', 2) = 2.0
#   ('C', 1, 73, 'South Wales', 1) = 2.0
#   ('C', 1, 75, 'South Wales', 4) = 2.0
#   ('C', 1, 78, 'South Wales', 1) = 1.0
#   ('C', 1, 81, 'South Wales', 4) = 2.0
#   ('C', 1, 82, 'South Wales', 2) = 2.0
#   ('C', 1, 88, 'South Wales', 1) = 2.0
#   ('C', 1, 89, 'South Wales', 4) = 2.0
#   ('C', 1, 93, 'South Wales', 4) = 2.0
#   ('C', 1, 94, 'South Wales', 4) = 2.0
#   ('C', 1, 95, 'South Wales', 4) = 2.0
#   ('C', 1, 102, 'South Wales', 1) = 2.0
#   ('C', 1, 106, 'South Wales', 2) = 2.0
#   ('C', 1, 108, 'South Wales', 2) = 2.0
#   ('C', 1, 108, 'South Wales', 3) = 2.0
#   ('C', 1, 112, 'South Wales', 4) = 2.0
#   ('C', 1, 116, 'South Wales', 4) = 1.0
#   ('C', 1, 117, 'South Wales', 1) = 2.0
#   ('C', 2, 1, 'IJmuiden', 4) = 2.0
#   ('C', 2, 2, 'IJmuiden', 2) = 2.0
#   ('C', 2, 3, 'IJmuiden', 3) = 2.0
#   ('C', 2, 4, 'IJmuiden', 1) = 2.0
#   ('C', 2, 7, 'IJmuiden', 3) = 2.0
#   ('C', 2, 7, 'IJmuiden', 4) = 2.0
#   ('C', 2, 8, 'IJmuiden', 4) = 2.0
#   ('C', 2, 10, 'IJmuiden', 4) = 2.0
#   ('C', 2, 12, 'IJmuiden', 3) = 2.0
#   ('C', 2, 16, 'IJmuiden', 3) = 2.0
#   ('C', 2, 16, 'IJmuiden', 4) = 2.0
#   ('C', 2, 22, 'IJmuiden', 3) = 2.0
#   ('C', 2, 23, 'IJmuiden', 1) = 2.0
#   ('C', 2, 23, 'IJmuiden', 2) = 2.0
#   ('C', 2, 24, 'IJmuiden', 3) = 1.0
#   ('C', 2, 25, 'IJmuiden', 2) = 2.0
#   ('C', 2, 26, 'IJmuiden', 1) = 2.0
#   ('C', 2, 29, 'IJmuiden', 3) = 2.0
#   ('C', 2, 30, 'IJmuiden', 1) = 2.0
#   ('C', 2, 30, 'IJmuiden', 3) = 2.0
#   ('C', 2, 32, 'IJmuiden', 1) = 2.0
#   ('C', 2, 32, 'IJmuiden', 3) = 2.0
#   ('C', 2, 33, 'IJmuiden', 1) = 2.0
#   ('C', 2, 36, 'IJmuiden', 1) = 2.0
#   ('C', 2, 37, 'IJmuiden', 1) = 1.0
#   ('C', 2, 39, 'IJmuiden', 2) = 2.0
#   ('C', 2, 40, 'IJmuiden', 2) = 2.0
#   ('C', 2, 40, 'IJmuiden', 4) = 2.0
#   ('C', 2, 42, 'IJmuiden', 4) = 2.0
#   ('C', 2, 43, 'IJmuiden', 1) = 1.0
#   ('C', 2, 44, 'IJmuiden', 3) = 2.0
#   ('C', 2, 45, 'IJmuiden', 1) = 2.0
#   ('C', 2, 47, 'IJmuiden', 2) = 2.0
#   ('C', 2, 49, 'IJmuiden', 1) = 2.0
#   ('C', 2, 50, 'IJmuiden', 1) = 2.0
#   ('C', 2, 1, 'Segal', 2) = 2.0
#   ('C', 2, 1, 'Segal', 3) = 2.0
#   ('C', 2, 4, 'Segal', 3) = 2.0
#   ('C', 2, 5, 'Segal', 2) = 1.0
#   ('C', 2, 6, 'Segal', 3) = 2.0
#   ('C', 2, 9, 'Segal', 1) = 1.0
#   ('C', 2, 9, 'Segal', 2) = 2.0
#   ('C', 2, 9, 'Segal', 3) = 2.0
#   ('C', 2, 12, 'Segal', 3) = 2.0
#   ('C', 2, 15, 'Segal', 1) = 2.0
#   ('C', 2, 15, 'Segal', 2) = 2.0
#   ('C', 2, 15, 'Segal', 3) = 2.0
#   ('C', 2, 18, 'Segal', 2) = 2.0
#   ('C', 2, 20, 'Segal', 2) = 2.0
#   ('C', 2, 21, 'Segal', 2) = 1.0
#   ('C', 2, 21, 'Segal', 3) = 2.0
#   ('C', 2, 22, 'Segal', 2) = 2.0
#   ('C', 2, 23, 'Segal', 3) = 2.0
#   ('C', 2, 24, 'Segal', 2) = 2.0
#   ('C', 2, 24, 'Segal', 3) = 2.0
#   ('C', 2, 25, 'Segal', 4) = 2.0
#   ('C', 2, 27, 'Segal', 2) = 2.0
#   ('C', 2, 28, 'Segal', 3) = 2.0
#   ('C', 2, 29, 'Segal', 2) = 2.0
#   ('C', 2, 29, 'Segal', 3) = 2.0
#   ('C', 2, 31, 'Segal', 1) = 2.0
#   ('C', 2, 31, 'Segal', 4) = 2.0
#   ('C', 2, 32, 'Segal', 3) = 2.0
#   ('C', 2, 33, 'Segal', 1) = 1.0
#   ('C', 2, 34, 'Segal', 2) = 2.0
#   ('C', 2, 35, 'Segal', 2) = 1.0
#   ('C', 2, 36, 'Segal', 2) = 1.0
#   ('C', 2, 37, 'Segal', 2) = 2.0
#   ('C', 2, 37, 'Segal', 3) = 2.0
#   ('C', 2, 39, 'Segal', 2) = 2.0
#   ('C', 2, 40, 'Segal', 3) = 2.0
#   ('C', 2, 40, 'Segal', 4) = 2.0
#   ('C', 2, 1, 'South Wales', 1) = 2.0
#   ('C', 2, 2, 'South Wales', 4) = 2.0
#   ('C', 2, 5, 'South Wales', 4) = 2.0
#   ('C', 2, 6, 'South Wales', 4) = 2.0
#   ('C', 2, 9, 'South Wales', 1) = 2.0
#   ('C', 2, 11, 'South Wales', 4) = 2.0
#   ('C', 2, 12, 'South Wales', 4) = 2.0
#   ('C', 2, 15, 'South Wales', 2) = 2.0
#   ('C', 2, 15, 'South Wales', 4) = 2.0
#   ('C', 2, 16, 'South Wales', 2) = 2.0
#   ('C', 2, 17, 'South Wales', 2) = 2.0
#   ('C', 2, 18, 'South Wales', 2) = 2.0
#   ('C', 2, 19, 'South Wales', 2) = 2.0
#   ('C', 2, 25, 'South Wales', 1) = 2.0
#   ('C', 2, 26, 'South Wales', 2) = 2.0
#   ('C', 2, 28, 'South Wales', 3) = 2.0
#   ('C', 2, 30, 'South Wales', 2) = 2.0
#   ('C', 2, 34, 'South Wales', 2) = 2.0
#   ('C', 2, 34, 'South Wales', 3) = 2.0
#   ('C', 2, 36, 'South Wales', 2) = 2.0
#   ('C', 2, 36, 'South Wales', 4) = 2.0
#   ('C', 2, 40, 'South Wales', 4) = 2.0
#   ('C', 2, 42, 'South Wales', 1) = 2.0
#   ('C', 2, 43, 'South Wales', 2) = 2.0
#   ('C', 2, 43, 'South Wales', 3) = 2.0
#   ('C', 2, 46, 'South Wales', 2) = 2.0
#   ('C', 2, 48, 'South Wales', 2) = 2.0
#   ('C', 2, 50, 'South Wales', 1) = 2.0
#   ('C', 2, 54, 'South Wales', 2) = 2.0
#   ('C', 2, 55, 'South Wales', 2) = 2.0
#   ('C', 2, 56, 'South Wales', 2) = 2.0
#   ('C', 2, 56, 'South Wales', 4) = 2.0
#   ('C', 2, 57, 'South Wales', 3) = 2.0
#   ('C', 2, 60, 'South Wales', 1) = 2.0
#   ('C', 2, 60, 'South Wales', 2) = 2.0
#   ('C', 2, 60, 'South Wales', 4) = 2.0
#   ('C', 2, 61, 'South Wales', 2) = 2.0
#   ('C', 2, 63, 'South Wales', 2) = 2.0
#   ('C', 2, 64, 'South Wales', 1) = 1.0
#   ('C', 2, 64, 'South Wales', 3) = 2.0
#   ('C', 2, 69, 'South Wales', 2) = 2.0
#   ('C', 2, 74, 'South Wales', 1) = 2.0
#   ('C', 2, 75, 'South Wales', 2) = 2.0
#   ('C', 2, 79, 'South Wales', 1) = 1.0
#   ('C', 2, 81, 'South Wales', 4) = 2.0
#   ('C', 2, 82, 'South Wales', 4) = 2.0
#   ('C', 2, 84, 'South Wales', 2) = 2.0
#   ('C', 2, 85, 'South Wales', 1) = 2.0
#   ('C', 2, 88, 'South Wales', 4) = 2.0
#   ('C', 2, 90, 'South Wales', 1) = 2.0
#   ('C', 2, 90, 'South Wales', 2) = 2.0
#   ('C', 2, 91, 'South Wales', 2) = 2.0
#   ('C', 2, 91, 'South Wales', 3) = 2.0
#   ('C', 2, 94, 'South Wales', 3) = 2.0
#   ('C', 2, 94, 'South Wales', 4) = 2.0
#   ('C', 2, 95, 'South Wales', 4) = 2.0
#   ('C', 2, 96, 'South Wales', 1) = 2.0
#   ('C', 2, 96, 'South Wales', 2) = 2.0
#   ('C', 2, 97, 'South Wales', 4) = 2.0
#   ('C', 2, 98, 'South Wales', 2) = 2.0
#   ('C', 2, 101, 'South Wales', 3) = 2.0
#   ('C', 2, 104, 'South Wales', 2) = 2.0
#   ('C', 2, 106, 'South Wales', 4) = 2.0
#   ('C', 2, 112, 'South Wales', 1) = 2.0
#   ('C', 2, 113, 'South Wales', 3) = 2.0
#   ('C', 2, 116, 'South Wales', 2) = 2.0
#   ('C', 2, 116, 'South Wales', 4) = 2.0
#
# Variable: y
#   (1, 1, 'IJmuiden', 1) = 1.0
#   (1, 1, 'IJmuiden', 2) = 1.0
#   (1, 1, 'IJmuiden', 3) = 1.0
#   (1, 1, 'IJmuiden', 4) = 1.0
#   (1, 2, 'IJmuiden', 1) = 1.0
#   (1, 2, 'IJmuiden', 2) = 1.0
#   (1, 3, 'IJmuiden', 1) = 1.0
#   (1, 3, 'IJmuiden', 3) = 1.0
#   (1, 4, 'IJmuiden', 1) = 1.0
#   (1, 5, 'IJmuiden', 1) = 1.0
#   (1, 5, 'IJmuiden', 2) = 1.0
#   (1, 5, 'IJmuiden', 3) = 1.0
#   (1, 5, 'IJmuiden', 4) = 1.0
#   (1, 6, 'IJmuiden', 2) = 1.0
#   (1, 7, 'IJmuiden', 2) = 1.0
#   (1, 8, 'IJmuiden', 1) = 1.0
#   (1, 8, 'IJmuiden', 4) = 1.0
#   (1, 9, 'IJmuiden', 1) = 1.0
#   (1, 9, 'IJmuiden', 2) = 1.0
#   (1, 9, 'IJmuiden', 4) = 1.0
#   (1, 10, 'IJmuiden', 1) = 1.0
#   (1, 10, 'IJmuiden', 2) = 1.0
#   (1, 11, 'IJmuiden', 1) = 1.0
#   (1, 11, 'IJmuiden', 2) = 1.0
#   (1, 11, 'IJmuiden', 4) = 1.0
#   (1, 13, 'IJmuiden', 2) = 1.0
#   (1, 14, 'IJmuiden', 1) = 1.0
#   (1, 15, 'IJmuiden', 1) = 1.0
#   (1, 15, 'IJmuiden', 3) = 1.0
#   (1, 18, 'IJmuiden', 4) = 1.0
#   (1, 19, 'IJmuiden', 1) = 1.0
#   (1, 20, 'IJmuiden', 2) = 1.0
#   (1, 20, 'IJmuiden', 3) = 1.0
#   (1, 20, 'IJmuiden', 4) = 1.0
#   (1, 21, 'IJmuiden', 1) = 1.0
#   (1, 21, 'IJmuiden', 2) = 1.0
#   (1, 21, 'IJmuiden', 4) = 1.0
#   (1, 23, 'IJmuiden', 4) = 1.0
#   (1, 24, 'IJmuiden', 1) = 1.0
#   (1, 24, 'IJmuiden', 2) = 1.0
#   (1, 24, 'IJmuiden', 3) = 1.0
#   (1, 24, 'IJmuiden', 4) = 1.0
#   (1, 25, 'IJmuiden', 2) = 1.0
#   (1, 25, 'IJmuiden', 4) = 1.0
#   (1, 26, 'IJmuiden', 1) = 1.0
#   (1, 26, 'IJmuiden', 3) = 1.0
#   (1, 27, 'IJmuiden', 1) = 1.0
#   (1, 28, 'IJmuiden', 1) = 1.0
#   (1, 29, 'IJmuiden', 1) = 1.0
#   (1, 30, 'IJmuiden', 1) = 1.0
#   (1, 30, 'IJmuiden', 2) = 1.0
#   (1, 30, 'IJmuiden', 3) = 1.0
#   (1, 30, 'IJmuiden', 4) = 1.0
#   (1, 31, 'IJmuiden', 1) = 1.0
#   (1, 31, 'IJmuiden', 2) = 1.0
#   (1, 32, 'IJmuiden', 1) = 1.0
#   (1, 32, 'IJmuiden', 2) = 1.0
#   (1, 32, 'IJmuiden', 3) = 1.0
#   (1, 32, 'IJmuiden', 4) = 1.0
#   (1, 33, 'IJmuiden', 2) = 1.0
#   (1, 33, 'IJmuiden', 3) = 1.0
#   (1, 33, 'IJmuiden', 4) = 1.0
#   (1, 34, 'IJmuiden', 1) = 1.0
#   (1, 34, 'IJmuiden', 4) = 1.0
#   (1, 35, 'IJmuiden', 2) = 1.0
#   (1, 36, 'IJmuiden', 1) = 1.0
#   (1, 39, 'IJmuiden', 1) = 1.0
#   (1, 39, 'IJmuiden', 3) = 1.0
#   (1, 39, 'IJmuiden', 4) = 1.0
#   (1, 40, 'IJmuiden', 3) = 1.0
#   (1, 40, 'IJmuiden', 4) = 1.0
#   (1, 41, 'IJmuiden', 1) = 1.0
#   (1, 41, 'IJmuiden', 4) = 1.0
#   (1, 42, 'IJmuiden', 3) = 1.0
#   (1, 42, 'IJmuiden', 4) = 1.0
#   (1, 43, 'IJmuiden', 4) = 1.0
#   (1, 45, 'IJmuiden', 2) = 1.0
#   (1, 45, 'IJmuiden', 4) = 1.0
#   (1, 46, 'IJmuiden', 1) = 1.0
#   (1, 46, 'IJmuiden', 3) = 1.0
#   (1, 47, 'IJmuiden', 1) = 1.0
#   (1, 47, 'IJmuiden', 3) = 1.0
#   (1, 47, 'IJmuiden', 4) = 1.0
#   (1, 48, 'IJmuiden', 1) = 1.0
#   (1, 48, 'IJmuiden', 3) = 1.0
#   (1, 48, 'IJmuiden', 4) = 1.0
#   (1, 49, 'IJmuiden', 4) = 1.0
#   (1, 50, 'IJmuiden', 1) = 1.0
#   (1, 50, 'IJmuiden', 4) = 1.0
#   (1, 1, 'Segal', 1) = 1.0
#   (1, 1, 'Segal', 2) = 1.0
#   (1, 1, 'Segal', 4) = 1.0
#   (1, 2, 'Segal', 4) = 1.0
#   (1, 3, 'Segal', 1) = 1.0
#   (1, 3, 'Segal', 2) = 1.0
#   (1, 3, 'Segal', 3) = 1.0
#   (1, 3, 'Segal', 4) = 1.0
#   (1, 4, 'Segal', 1) = 1.0
#   (1, 5, 'Segal', 3) = 1.0
#   (1, 5, 'Segal', 4) = 1.0
#   (1, 6, 'Segal', 1) = 1.0
#   (1, 6, 'Segal', 2) = 1.0
#   (1, 7, 'Segal', 3) = 1.0
#   (1, 7, 'Segal', 4) = 1.0
#   (1, 8, 'Segal', 1) = 1.0
#   (1, 8, 'Segal', 3) = 1.0
#   (1, 9, 'Segal', 3) = 1.0
#   (1, 9, 'Segal', 4) = 1.0
#   (1, 10, 'Segal', 1) = 1.0
#   (1, 11, 'Segal', 1) = 1.0
#   (1, 11, 'Segal', 3) = 1.0
#   (1, 11, 'Segal', 4) = 1.0
#   (1, 13, 'Segal', 4) = 1.0
#   (1, 15, 'Segal', 1) = 1.0
#   (1, 15, 'Segal', 3) = 1.0
#   (1, 15, 'Segal', 4) = 1.0
#   (1, 16, 'Segal', 1) = 1.0
#   (1, 17, 'Segal', 1) = 1.0
#   (1, 17, 'Segal', 2) = 1.0
#   (1, 18, 'Segal', 2) = 1.0
#   (1, 18, 'Segal', 3) = 1.0
#   (1, 19, 'Segal', 1) = 1.0
#   (1, 19, 'Segal', 3) = 1.0
#   (1, 19, 'Segal', 4) = 1.0
#   (1, 20, 'Segal', 1) = 1.0
#   (1, 20, 'Segal', 2) = 1.0
#   (1, 21, 'Segal', 2) = 1.0
#   (1, 21, 'Segal', 4) = 1.0
#   (1, 23, 'Segal', 1) = 1.0
#   (1, 23, 'Segal', 4) = 1.0
#   (1, 24, 'Segal', 4) = 1.0
#   (1, 25, 'Segal', 1) = 1.0
#   (1, 25, 'Segal', 3) = 1.0
#   (1, 26, 'Segal', 1) = 1.0
#   (1, 26, 'Segal', 2) = 1.0
#   (1, 27, 'Segal', 1) = 1.0
#   (1, 27, 'Segal', 3) = 1.0
#   (1, 28, 'Segal', 1) = 1.0
#   (1, 29, 'Segal', 1) = 1.0
#   (1, 29, 'Segal', 4) = 1.0
#   (1, 30, 'Segal', 1) = 1.0
#   (1, 33, 'Segal', 3) = 1.0
#   (1, 34, 'Segal', 1) = 1.0
#   (1, 34, 'Segal', 4) = 1.0
#   (1, 35, 'Segal', 2) = 1.0
#   (1, 35, 'Segal', 4) = 1.0
#   (1, 37, 'Segal', 1) = 1.0
#   (1, 37, 'Segal', 3) = 1.0
#   (1, 37, 'Segal', 4) = 1.0
#   (1, 38, 'Segal', 1) = 1.0
#   (1, 38, 'Segal', 2) = 1.0
#   (1, 38, 'Segal', 4) = 1.0
#   (1, 39, 'Segal', 2) = 1.0
#   (1, 39, 'Segal', 4) = 1.0
#   (1, 40, 'Segal', 1) = 1.0
#   (1, 40, 'Segal', 3) = 1.0
#   (1, 40, 'Segal', 4) = 1.0
#   (1, 41, 'Segal', 1) = 1.0
#   (1, 41, 'Segal', 3) = 1.0
#   (1, 41, 'Segal', 4) = 1.0
#   (1, 42, 'Segal', 1) = 1.0
#   (1, 1, 'South Wales', 1) = 1.0
#   (1, 2, 'South Wales', 1) = 1.0
#   (1, 2, 'South Wales', 4) = 1.0
#   (1, 3, 'South Wales', 2) = 1.0
#   (1, 3, 'South Wales', 3) = 1.0
#   (1, 3, 'South Wales', 4) = 1.0
#   (1, 4, 'South Wales', 1) = 1.0
#   (1, 4, 'South Wales', 2) = 1.0
#   (1, 4, 'South Wales', 3) = 1.0
#   (1, 4, 'South Wales', 4) = 1.0
#   (1, 5, 'South Wales', 4) = 1.0
#   (1, 6, 'South Wales', 1) = 1.0
#   (1, 6, 'South Wales', 4) = 1.0
#   (1, 7, 'South Wales', 2) = 1.0
#   (1, 7, 'South Wales', 4) = 1.0
#   (1, 8, 'South Wales', 1) = 1.0
#   (1, 8, 'South Wales', 4) = 1.0
#   (1, 9, 'South Wales', 1) = 1.0
#   (1, 9, 'South Wales', 2) = 1.0
#   (1, 9, 'South Wales', 4) = 1.0
#   (1, 10, 'South Wales', 1) = 1.0
#   (1, 10, 'South Wales', 2) = 1.0
#   (1, 10, 'South Wales', 4) = 1.0
#   (1, 11, 'South Wales', 3) = 1.0
#   (1, 12, 'South Wales', 1) = 1.0
#   (1, 12, 'South Wales', 4) = 1.0
#   (1, 13, 'South Wales', 1) = 1.0
#   (1, 13, 'South Wales', 3) = 1.0
#   (1, 13, 'South Wales', 4) = 1.0
#   (1, 14, 'South Wales', 1) = 1.0
#   (1, 14, 'South Wales', 4) = 1.0
#   (1, 15, 'South Wales', 4) = 1.0
#   (1, 16, 'South Wales', 4) = 1.0
#   (1, 17, 'South Wales', 2) = 1.0
#   (1, 17, 'South Wales', 3) = 1.0
#   (1, 17, 'South Wales', 4) = 1.0
#   (1, 19, 'South Wales', 2) = 1.0
#   (1, 21, 'South Wales', 2) = 1.0
#   (1, 21, 'South Wales', 3) = 1.0
#   (1, 21, 'South Wales', 4) = 1.0
#   (1, 22, 'South Wales', 1) = 1.0
#   (1, 22, 'South Wales', 3) = 1.0
#   (1, 22, 'South Wales', 4) = 1.0
#   (1, 23, 'South Wales', 1) = 1.0
#   (1, 23, 'South Wales', 4) = 1.0
#   (1, 24, 'South Wales', 1) = 1.0
#   (1, 24, 'South Wales', 3) = 1.0
#   (1, 24, 'South Wales', 4) = 1.0
#   (1, 25, 'South Wales', 1) = 1.0
#   (1, 25, 'South Wales', 2) = 1.0
#   (1, 25, 'South Wales', 3) = 1.0
#   (1, 26, 'South Wales', 4) = 1.0
#   (1, 27, 'South Wales', 2) = 1.0
#   (1, 27, 'South Wales', 4) = 1.0
#   (1, 28, 'South Wales', 3) = 1.0
#   (1, 28, 'South Wales', 4) = 1.0
#   (1, 29, 'South Wales', 1) = 1.0
#   (1, 29, 'South Wales', 4) = 1.0
#   (1, 30, 'South Wales', 2) = 1.0
#   (1, 30, 'South Wales', 4) = 1.0
#   (1, 31, 'South Wales', 1) = 1.0
#   (1, 31, 'South Wales', 2) = 1.0
#   (1, 32, 'South Wales', 2) = 1.0
#   (1, 32, 'South Wales', 4) = 1.0
#   (1, 33, 'South Wales', 1) = 1.0
#   (1, 33, 'South Wales', 2) = 1.0
#   (1, 33, 'South Wales', 4) = 1.0
#   (1, 34, 'South Wales', 4) = 1.0
#   (1, 35, 'South Wales', 2) = 1.0
#   (1, 37, 'South Wales', 1) = 1.0
#   (1, 37, 'South Wales', 2) = 1.0
#   (1, 39, 'South Wales', 4) = 1.0
#   (1, 40, 'South Wales', 3) = 1.0
#   (1, 41, 'South Wales', 1) = 1.0
#   (1, 41, 'South Wales', 2) = 1.0
#   (1, 42, 'South Wales', 1) = 1.0
#   (1, 42, 'South Wales', 2) = 1.0
#   (1, 43, 'South Wales', 3) = 1.0
#   (1, 44, 'South Wales', 1) = 1.0
#   (1, 44, 'South Wales', 2) = 1.0
#   (1, 45, 'South Wales', 1) = 1.0
#   (1, 46, 'South Wales', 1) = 1.0
#   (1, 46, 'South Wales', 2) = 1.0
#   (1, 47, 'South Wales', 1) = 1.0
#   (1, 47, 'South Wales', 2) = 1.0
#   (1, 48, 'South Wales', 1) = 1.0
#   (1, 49, 'South Wales', 1) = 1.0
#   (1, 49, 'South Wales', 4) = 1.0
#   (1, 50, 'South Wales', 1) = 1.0
#   (1, 50, 'South Wales', 2) = 1.0
#   (1, 50, 'South Wales', 4) = 1.0
#   (1, 51, 'South Wales', 2) = 1.0
#   (1, 52, 'South Wales', 2) = 1.0
#   (1, 52, 'South Wales', 3) = 1.0
#   (1, 52, 'South Wales', 4) = 1.0
#   (1, 53, 'South Wales', 2) = 1.0
#   (1, 54, 'South Wales', 1) = 1.0
#   (1, 55, 'South Wales', 2) = 1.0
#   (1, 55, 'South Wales', 4) = 1.0
#   (1, 56, 'South Wales', 1) = 1.0
#   (1, 56, 'South Wales', 4) = 1.0
#   (1, 57, 'South Wales', 1) = 1.0
#   (1, 57, 'South Wales', 2) = 1.0
#   (1, 57, 'South Wales', 3) = 1.0
#   (1, 57, 'South Wales', 4) = 1.0
#   (1, 58, 'South Wales', 4) = 1.0
#   (1, 59, 'South Wales', 2) = 1.0
#   (1, 59, 'South Wales', 4) = 1.0
#   (1, 60, 'South Wales', 1) = 1.0
#   (1, 61, 'South Wales', 2) = 1.0
#   (1, 62, 'South Wales', 1) = 1.0
#   (1, 62, 'South Wales', 2) = 1.0
#   (1, 62, 'South Wales', 3) = 1.0
#   (1, 63, 'South Wales', 4) = 1.0
#   (1, 64, 'South Wales', 1) = 1.0
#   (1, 64, 'South Wales', 2) = 1.0
#   (1, 65, 'South Wales', 2) = 1.0
#   (1, 66, 'South Wales', 1) = 1.0
#   (1, 66, 'South Wales', 2) = 1.0
#   (1, 66, 'South Wales', 4) = 1.0
#   (1, 67, 'South Wales', 2) = 1.0
#   (1, 67, 'South Wales', 4) = 1.0
#   (1, 68, 'South Wales', 2) = 1.0
#   (1, 68, 'South Wales', 4) = 1.0
#   (1, 69, 'South Wales', 4) = 1.0
#   (1, 71, 'South Wales', 1) = 1.0
#   (1, 71, 'South Wales', 2) = 1.0
#   (1, 71, 'South Wales', 3) = 1.0
#   (1, 71, 'South Wales', 4) = 1.0
#   (1, 72, 'South Wales', 2) = 1.0
#   (1, 72, 'South Wales', 3) = 1.0
#   (1, 73, 'South Wales', 1) = 1.0
#   (1, 73, 'South Wales', 4) = 1.0
#   (1, 74, 'South Wales', 2) = 1.0
#   (1, 74, 'South Wales', 4) = 1.0
#   (1, 75, 'South Wales', 4) = 1.0
#   (1, 76, 'South Wales', 4) = 1.0
#   (1, 77, 'South Wales', 3) = 1.0
#   (1, 78, 'South Wales', 1) = 1.0
#   (1, 78, 'South Wales', 2) = 1.0
#   (1, 79, 'South Wales', 4) = 1.0
#   (1, 80, 'South Wales', 4) = 1.0
#   (1, 81, 'South Wales', 4) = 1.0
#   (1, 82, 'South Wales', 2) = 1.0
#   (1, 82, 'South Wales', 4) = 1.0
#   (1, 83, 'South Wales', 4) = 1.0
#   (1, 84, 'South Wales', 2) = 1.0
#   (1, 84, 'South Wales', 4) = 1.0
#   (1, 86, 'South Wales', 4) = 1.0
#   (1, 88, 'South Wales', 1) = 1.0
#   (1, 88, 'South Wales', 4) = 1.0
#   (1, 89, 'South Wales', 1) = 1.0
#   (1, 89, 'South Wales', 4) = 1.0
#   (1, 90, 'South Wales', 2) = 1.0
#   (1, 90, 'South Wales', 3) = 1.0
#   (1, 90, 'South Wales', 4) = 1.0
#   (1, 91, 'South Wales', 1) = 1.0
#   (1, 91, 'South Wales', 2) = 1.0
#   (1, 91, 'South Wales', 3) = 1.0
#   (1, 91, 'South Wales', 4) = 1.0
#   (1, 93, 'South Wales', 1) = 1.0
#   (1, 93, 'South Wales', 3) = 1.0
#   (1, 93, 'South Wales', 4) = 1.0
#   (1, 94, 'South Wales', 1) = 1.0
#   (1, 94, 'South Wales', 2) = 1.0
#   (1, 94, 'South Wales', 4) = 1.0
#   (1, 95, 'South Wales', 1) = 1.0
#   (1, 95, 'South Wales', 4) = 1.0
#   (1, 96, 'South Wales', 1) = 1.0
#   (1, 96, 'South Wales', 2) = 1.0
#   (1, 97, 'South Wales', 3) = 1.0
#   (1, 98, 'South Wales', 1) = 1.0
#   (1, 98, 'South Wales', 2) = 1.0
#   (1, 99, 'South Wales', 2) = 1.0
#   (1, 99, 'South Wales', 3) = 1.0
#   (1, 100, 'South Wales', 2) = 1.0
#   (1, 102, 'South Wales', 1) = 1.0
#   (1, 102, 'South Wales', 2) = 1.0
#   (1, 102, 'South Wales', 4) = 1.0
#   (1, 103, 'South Wales', 2) = 1.0
#   (1, 103, 'South Wales', 4) = 1.0
#   (1, 104, 'South Wales', 2) = 1.0
#   (1, 105, 'South Wales', 4) = 1.0
#   (1, 106, 'South Wales', 1) = 1.0
#   (1, 106, 'South Wales', 2) = 1.0
#   (1, 107, 'South Wales', 4) = 1.0
#   (1, 108, 'South Wales', 1) = 1.0
#   (1, 108, 'South Wales', 2) = 1.0
#   (1, 108, 'South Wales', 3) = 1.0
#   (1, 109, 'South Wales', 1) = 1.0
#   (1, 110, 'South Wales', 2) = 1.0
#   (1, 111, 'South Wales', 2) = 1.0
#   (1, 112, 'South Wales', 4) = 1.0
#   (1, 114, 'South Wales', 4) = 1.0
#   (1, 116, 'South Wales', 1) = 1.0
#   (1, 116, 'South Wales', 4) = 1.0
#   (1, 117, 'South Wales', 1) = 1.0
#   (1, 117, 'South Wales', 3) = 1.0
#   (2, 1, 'IJmuiden', 1) = 1.0
#   (2, 1, 'IJmuiden', 4) = 1.0
#   (2, 2, 'IJmuiden', 2) = 1.0
#   (2, 3, 'IJmuiden', 3) = 1.0
#   (2, 4, 'IJmuiden', 1) = 1.0
#   (2, 4, 'IJmuiden', 3) = 1.0
#   (2, 5, 'IJmuiden', 2) = 1.0
#   (2, 6, 'IJmuiden', 4) = 1.0
#   (2, 7, 'IJmuiden', 3) = 1.0
#   (2, 7, 'IJmuiden', 4) = 1.0
#   (2, 8, 'IJmuiden', 4) = 1.0
#   (2, 9, 'IJmuiden', 2) = 1.0
#   (2, 10, 'IJmuiden', 2) = 1.0
#   (2, 10, 'IJmuiden', 4) = 1.0
#   (2, 11, 'IJmuiden', 1) = 1.0
#   (2, 11, 'IJmuiden', 2) = 1.0
#   (2, 12, 'IJmuiden', 2) = 1.0
#   (2, 12, 'IJmuiden', 3) = 1.0
#   (2, 12, 'IJmuiden', 4) = 1.0
#   (2, 13, 'IJmuiden', 2) = 1.0
#   (2, 15, 'IJmuiden', 1) = 1.0
#   (2, 15, 'IJmuiden', 2) = 1.0
#   (2, 16, 'IJmuiden', 2) = 1.0
#   (2, 16, 'IJmuiden', 3) = 1.0
#   (2, 16, 'IJmuiden', 4) = 1.0
#   (2, 17, 'IJmuiden', 3) = 1.0
#   (2, 17, 'IJmuiden', 4) = 1.0
#   (2, 18, 'IJmuiden', 2) = 1.0
#   (2, 18, 'IJmuiden', 3) = 1.0
#   (2, 19, 'IJmuiden', 4) = 1.0
#   (2, 20, 'IJmuiden', 4) = 1.0
#   (2, 21, 'IJmuiden', 4) = 1.0
#   (2, 22, 'IJmuiden', 1) = 1.0
#   (2, 22, 'IJmuiden', 2) = 1.0
#   (2, 22, 'IJmuiden', 3) = 1.0
#   (2, 23, 'IJmuiden', 1) = 1.0
#   (2, 23, 'IJmuiden', 2) = 1.0
#   (2, 23, 'IJmuiden', 3) = 1.0
#   (2, 24, 'IJmuiden', 3) = 1.0
#   (2, 24, 'IJmuiden', 4) = 1.0
#   (2, 25, 'IJmuiden', 1) = 1.0
#   (2, 25, 'IJmuiden', 2) = 1.0
#   (2, 25, 'IJmuiden', 3) = 1.0
#   (2, 26, 'IJmuiden', 1) = 1.0
#   (2, 26, 'IJmuiden', 2) = 1.0
#   (2, 26, 'IJmuiden', 4) = 1.0
#   (2, 27, 'IJmuiden', 3) = 1.0
#   (2, 28, 'IJmuiden', 1) = 1.0
#   (2, 28, 'IJmuiden', 4) = 1.0
#   (2, 29, 'IJmuiden', 3) = 1.0
#   (2, 29, 'IJmuiden', 4) = 1.0
#   (2, 30, 'IJmuiden', 1) = 1.0
#   (2, 30, 'IJmuiden', 3) = 1.0
#   (2, 30, 'IJmuiden', 4) = 1.0
#   (2, 32, 'IJmuiden', 1) = 1.0
#   (2, 32, 'IJmuiden', 2) = 1.0
#   (2, 32, 'IJmuiden', 3) = 1.0
#   (2, 33, 'IJmuiden', 1) = 1.0
#   (2, 33, 'IJmuiden', 4) = 1.0
#   (2, 36, 'IJmuiden', 1) = 1.0
#   (2, 36, 'IJmuiden', 4) = 1.0
#   (2, 37, 'IJmuiden', 1) = 1.0
#   (2, 37, 'IJmuiden', 3) = 1.0
#   (2, 38, 'IJmuiden', 2) = 1.0
#   (2, 39, 'IJmuiden', 2) = 1.0
#   (2, 39, 'IJmuiden', 3) = 1.0
#   (2, 40, 'IJmuiden', 2) = 1.0
#   (2, 40, 'IJmuiden', 4) = 1.0
#   (2, 41, 'IJmuiden', 3) = 1.0
#   (2, 42, 'IJmuiden', 4) = 1.0
#   (2, 43, 'IJmuiden', 1) = 1.0
#   (2, 44, 'IJmuiden', 3) = 1.0
#   (2, 45, 'IJmuiden', 1) = 1.0
#   (2, 45, 'IJmuiden', 2) = 1.0
#   (2, 45, 'IJmuiden', 3) = 1.0
#   (2, 46, 'IJmuiden', 1) = 1.0
#   (2, 46, 'IJmuiden', 2) = 1.0
#   (2, 47, 'IJmuiden', 2) = 1.0
#   (2, 48, 'IJmuiden', 1) = 1.0
#   (2, 48, 'IJmuiden', 2) = 1.0
#   (2, 48, 'IJmuiden', 4) = 1.0
#   (2, 49, 'IJmuiden', 1) = 1.0
#   (2, 49, 'IJmuiden', 2) = 1.0
#   (2, 50, 'IJmuiden', 1) = 1.0
#   (2, 1, 'Segal', 2) = 1.0
#   (2, 1, 'Segal', 3) = 1.0
#   (2, 1, 'Segal', 4) = 1.0
#   (2, 2, 'Segal', 1) = 1.0
#   (2, 2, 'Segal', 2) = 1.0
#   (2, 2, 'Segal', 3) = 1.0
#   (2, 2, 'Segal', 4) = 1.0
#   (2, 3, 'Segal', 1) = 1.0
#   (2, 4, 'Segal', 3) = 1.0
#   (2, 5, 'Segal', 2) = 1.0
#   (2, 5, 'Segal', 3) = 1.0
#   (2, 6, 'Segal', 3) = 1.0
#   (2, 7, 'Segal', 1) = 1.0
#   (2, 7, 'Segal', 3) = 1.0
#   (2, 7, 'Segal', 4) = 1.0
#   (2, 9, 'Segal', 1) = 1.0
#   (2, 9, 'Segal', 2) = 1.0
#   (2, 9, 'Segal', 3) = 1.0
#   (2, 9, 'Segal', 4) = 1.0
#   (2, 10, 'Segal', 4) = 1.0
#   (2, 11, 'Segal', 4) = 1.0
#   (2, 12, 'Segal', 3) = 1.0
#   (2, 13, 'Segal', 3) = 1.0
#   (2, 13, 'Segal', 4) = 1.0
#   (2, 14, 'Segal', 3) = 1.0
#   (2, 15, 'Segal', 1) = 1.0
#   (2, 15, 'Segal', 2) = 1.0
#   (2, 15, 'Segal', 3) = 1.0
#   (2, 17, 'Segal', 2) = 1.0
#   (2, 18, 'Segal', 2) = 1.0
#   (2, 18, 'Segal', 4) = 1.0
#   (2, 20, 'Segal', 2) = 1.0
#   (2, 21, 'Segal', 2) = 1.0
#   (2, 21, 'Segal', 3) = 1.0
#   (2, 21, 'Segal', 4) = 1.0
#   (2, 22, 'Segal', 2) = 1.0
#   (2, 23, 'Segal', 2) = 1.0
#   (2, 23, 'Segal', 3) = 1.0
#   (2, 24, 'Segal', 2) = 1.0
#   (2, 24, 'Segal', 3) = 1.0
#   (2, 25, 'Segal', 4) = 1.0
#   (2, 26, 'Segal', 2) = 1.0
#   (2, 26, 'Segal', 4) = 1.0
#   (2, 27, 'Segal', 1) = 1.0
#   (2, 27, 'Segal', 2) = 1.0
#   (2, 28, 'Segal', 2) = 1.0
#   (2, 28, 'Segal', 3) = 1.0
#   (2, 28, 'Segal', 4) = 1.0
#   (2, 29, 'Segal', 2) = 1.0
#   (2, 29, 'Segal', 3) = 1.0
#   (2, 30, 'Segal', 3) = 1.0
#   (2, 31, 'Segal', 1) = 1.0
#   (2, 31, 'Segal', 4) = 1.0
#   (2, 32, 'Segal', 3) = 1.0
#   (2, 33, 'Segal', 1) = 1.0
#   (2, 33, 'Segal', 3) = 1.0
#   (2, 33, 'Segal', 4) = 1.0
#   (2, 34, 'Segal', 2) = 1.0
#   (2, 34, 'Segal', 3) = 1.0
#   (2, 34, 'Segal', 4) = 1.0
#   (2, 35, 'Segal', 2) = 1.0
#   (2, 35, 'Segal', 3) = 1.0
#   (2, 36, 'Segal', 2) = 1.0
#   (2, 37, 'Segal', 2) = 1.0
#   (2, 37, 'Segal', 3) = 1.0
#   (2, 38, 'Segal', 1) = 1.0
#   (2, 38, 'Segal', 2) = 1.0
#   (2, 39, 'Segal', 1) = 1.0
#   (2, 39, 'Segal', 2) = 1.0
#   (2, 40, 'Segal', 1) = 1.0
#   (2, 40, 'Segal', 3) = 1.0
#   (2, 40, 'Segal', 4) = 1.0
#   (2, 42, 'Segal', 4) = 1.0
#   (2, 1, 'South Wales', 1) = 1.0
#   (2, 1, 'South Wales', 4) = 1.0
#   (2, 2, 'South Wales', 2) = 1.0
#   (2, 2, 'South Wales', 4) = 1.0
#   (2, 4, 'South Wales', 2) = 1.0
#   (2, 5, 'South Wales', 1) = 1.0
#   (2, 5, 'South Wales', 4) = 1.0
#   (2, 6, 'South Wales', 4) = 1.0
#   (2, 8, 'South Wales', 4) = 1.0
#   (2, 9, 'South Wales', 1) = 1.0
#   (2, 9, 'South Wales', 4) = 1.0
#   (2, 10, 'South Wales', 4) = 1.0
#   (2, 11, 'South Wales', 4) = 1.0
#   (2, 12, 'South Wales', 4) = 1.0
#   (2, 13, 'South Wales', 2) = 1.0
#   (2, 13, 'South Wales', 3) = 1.0
#   (2, 13, 'South Wales', 4) = 1.0
#   (2, 14, 'South Wales', 1) = 1.0
#   (2, 15, 'South Wales', 2) = 1.0
#   (2, 15, 'South Wales', 4) = 1.0
#   (2, 16, 'South Wales', 2) = 1.0
#   (2, 16, 'South Wales', 4) = 1.0
#   (2, 17, 'South Wales', 2) = 1.0
#   (2, 18, 'South Wales', 1) = 1.0
#   (2, 18, 'South Wales', 2) = 1.0
#   (2, 19, 'South Wales', 1) = 1.0
#   (2, 19, 'South Wales', 2) = 1.0
#   (2, 22, 'South Wales', 2) = 1.0
#   (2, 22, 'South Wales', 3) = 1.0
#   (2, 24, 'South Wales', 1) = 1.0
#   (2, 24, 'South Wales', 4) = 1.0
#   (2, 25, 'South Wales', 1) = 1.0
#   (2, 26, 'South Wales', 1) = 1.0
#   (2, 26, 'South Wales', 2) = 1.0
#   (2, 27, 'South Wales', 1) = 1.0
#   (2, 27, 'South Wales', 4) = 1.0
#   (2, 28, 'South Wales', 1) = 1.0
#   (2, 28, 'South Wales', 3) = 1.0
#   (2, 29, 'South Wales', 3) = 1.0
#   (2, 30, 'South Wales', 1) = 1.0
#   (2, 30, 'South Wales', 2) = 1.0
#   (2, 30, 'South Wales', 4) = 1.0
#   (2, 32, 'South Wales', 1) = 1.0
#   (2, 32, 'South Wales', 4) = 1.0
#   (2, 33, 'South Wales', 3) = 1.0
#   (2, 34, 'South Wales', 2) = 1.0
#   (2, 34, 'South Wales', 3) = 1.0
#   (2, 34, 'South Wales', 4) = 1.0
#   (2, 35, 'South Wales', 1) = 1.0
#   (2, 36, 'South Wales', 2) = 1.0
#   (2, 36, 'South Wales', 4) = 1.0
#   (2, 37, 'South Wales', 3) = 1.0
#   (2, 39, 'South Wales', 4) = 1.0
#   (2, 40, 'South Wales', 4) = 1.0
#   (2, 41, 'South Wales', 2) = 1.0
#   (2, 42, 'South Wales', 1) = 1.0
#   (2, 42, 'South Wales', 3) = 1.0
#   (2, 43, 'South Wales', 1) = 1.0
#   (2, 43, 'South Wales', 2) = 1.0
#   (2, 43, 'South Wales', 3) = 1.0
#   (2, 46, 'South Wales', 2) = 1.0
#   (2, 48, 'South Wales', 2) = 1.0
#   (2, 48, 'South Wales', 4) = 1.0
#   (2, 49, 'South Wales', 1) = 1.0
#   (2, 49, 'South Wales', 3) = 1.0
#   (2, 50, 'South Wales', 1) = 1.0
#   (2, 50, 'South Wales', 2) = 1.0
#   (2, 51, 'South Wales', 1) = 1.0
#   (2, 53, 'South Wales', 1) = 1.0
#   (2, 53, 'South Wales', 4) = 1.0
#   (2, 54, 'South Wales', 2) = 1.0
#   (2, 55, 'South Wales', 2) = 1.0
#   (2, 56, 'South Wales', 2) = 1.0
#   (2, 56, 'South Wales', 4) = 1.0
#   (2, 57, 'South Wales', 3) = 1.0
#   (2, 58, 'South Wales', 4) = 1.0
#   (2, 59, 'South Wales', 1) = 1.0
#   (2, 59, 'South Wales', 2) = 1.0
#   (2, 60, 'South Wales', 1) = 1.0
#   (2, 60, 'South Wales', 2) = 1.0
#   (2, 60, 'South Wales', 4) = 1.0
#   (2, 61, 'South Wales', 2) = 1.0
#   (2, 61, 'South Wales', 4) = 1.0
#   (2, 62, 'South Wales', 2) = 1.0
#   (2, 63, 'South Wales', 2) = 1.0
#   (2, 64, 'South Wales', 1) = 1.0
#   (2, 64, 'South Wales', 3) = 1.0
#   (2, 65, 'South Wales', 1) = 1.0
#   (2, 65, 'South Wales', 2) = 1.0
#   (2, 66, 'South Wales', 1) = 1.0
#   (2, 66, 'South Wales', 3) = 1.0
#   (2, 67, 'South Wales', 4) = 1.0
#   (2, 69, 'South Wales', 2) = 1.0
#   (2, 70, 'South Wales', 2) = 1.0
#   (2, 72, 'South Wales', 4) = 1.0
#   (2, 73, 'South Wales', 2) = 1.0
#   (2, 74, 'South Wales', 1) = 1.0
#   (2, 74, 'South Wales', 4) = 1.0
#   (2, 75, 'South Wales', 2) = 1.0
#   (2, 78, 'South Wales', 4) = 1.0
#   (2, 79, 'South Wales', 1) = 1.0
#   (2, 79, 'South Wales', 4) = 1.0
#   (2, 80, 'South Wales', 4) = 1.0
#   (2, 81, 'South Wales', 4) = 1.0
#   (2, 82, 'South Wales', 4) = 1.0
#   (2, 84, 'South Wales', 2) = 1.0
#   (2, 84, 'South Wales', 4) = 1.0
#   (2, 85, 'South Wales', 1) = 1.0
#   (2, 85, 'South Wales', 3) = 1.0
#   (2, 86, 'South Wales', 4) = 1.0
#   (2, 87, 'South Wales', 2) = 1.0
#   (2, 87, 'South Wales', 4) = 1.0
#   (2, 88, 'South Wales', 4) = 1.0
#   (2, 90, 'South Wales', 1) = 1.0
#   (2, 90, 'South Wales', 2) = 1.0
#   (2, 90, 'South Wales', 4) = 1.0
#   (2, 91, 'South Wales', 2) = 1.0
#   (2, 91, 'South Wales', 3) = 1.0
#   (2, 92, 'South Wales', 2) = 1.0
#   (2, 92, 'South Wales', 4) = 1.0
#   (2, 93, 'South Wales', 2) = 1.0
#   (2, 94, 'South Wales', 2) = 1.0
#   (2, 94, 'South Wales', 3) = 1.0
#   (2, 94, 'South Wales', 4) = 1.0
#   (2, 95, 'South Wales', 4) = 1.0
#   (2, 96, 'South Wales', 1) = 1.0
#   (2, 96, 'South Wales', 2) = 1.0
#   (2, 96, 'South Wales', 4) = 1.0
#   (2, 97, 'South Wales', 2) = 1.0
#   (2, 97, 'South Wales', 4) = 1.0
#   (2, 98, 'South Wales', 1) = 1.0
#   (2, 98, 'South Wales', 2) = 1.0
#   (2, 99, 'South Wales', 1) = 1.0
#   (2, 100, 'South Wales', 4) = 1.0
#   (2, 101, 'South Wales', 2) = 1.0
#   (2, 101, 'South Wales', 3) = 1.0
#   (2, 102, 'South Wales', 1) = 1.0
#   (2, 102, 'South Wales', 2) = 1.0
#   (2, 102, 'South Wales', 4) = 1.0
#   (2, 104, 'South Wales', 2) = 1.0
#   (2, 104, 'South Wales', 3) = 1.0
#   (2, 106, 'South Wales', 4) = 1.0
#   (2, 107, 'South Wales', 2) = 1.0
#   (2, 107, 'South Wales', 3) = 1.0
#   (2, 107, 'South Wales', 4) = 1.0
#   (2, 108, 'South Wales', 2) = 1.0
#   (2, 109, 'South Wales', 2) = 1.0
#   (2, 110, 'South Wales', 1) = 1.0
#   (2, 110, 'South Wales', 2) = 1.0
#   (2, 111, 'South Wales', 1) = 1.0
#   (2, 112, 'South Wales', 1) = 1.0
#   (2, 113, 'South Wales', 1) = 1.0
#   (2, 113, 'South Wales', 3) = 1.0
#   (2, 115, 'South Wales', 4) = 1.0
#   (2, 116, 'South Wales', 1) = 1.0
#   (2, 116, 'South Wales', 2) = 1.0
#   (2, 116, 'South Wales', 4) = 1.0
#
# Variable: z
#   ('IJmuiden', 'Bochum', 1) = 1.0
#   ('IJmuiden', 'Dortmund', 4) = 1.0
#   ('IJmuiden', 'Gelsenkirchen', 1) = 1.0
#   ('IJmuiden', 'Gelsenkirchen', 2) = 1.0
#   ('IJmuiden', 'Hagen', 3) = 1.0
#   ('IJmuiden', 'Iserlohn', 4) = 1.0
#   ('IJmuiden', 'Neuss', 1) = 1.0
#   ('IJmuiden', 'Schwerte', 1) = 1.0
#   ('Segal', 'Boenen', 3) = 1.0
#   ('Segal', 'Boenen', 4) = 1.0
#   ('Segal', 'Gelsenkirchen', 4) = 1.0
#   ('Segal', 'Iserlohn', 1) = 1.0
#   ('Segal', 'Iserlohn', 3) = 1.0
#   ('Segal', 'Neuss', 2) = 1.0
#   ('South Wales', 'Bochum', 3) = 1.0
#   ('South Wales', 'Boenen', 1) = 1.0
#   ('South Wales', 'Dortmund', 1) = 1.0
#   ('South Wales', 'Hagen', 1) = 1.0
#   ('South Wales', 'Hagen', 2) = 1.0
#   ('South Wales', 'Hagen', 4) = 1.0
#   ('South Wales', 'Iserlohn', 2) = 1.0
#   ('South Wales', 'Neuss', 3) = 1.0
#   ('South Wales', 'Neuss', 4) = 1.0
#   ('South Wales', 'Schwerte', 2) = 1.0
#
# Variable: i
#   ('Bochum', 'A', 1) = 6.0
#   ('Bochum', 'A', 3) = 3.0
#   ('Bochum', 'B', 1) = 5.0
#   ('Bochum', 'B', 3) = 8.0
#   ('Bochum', 'C', 1) = 7.0
#   ('Bochum', 'C', 3) = 7.0
#   ('Boenen', 'A', 1) = 8.0
#   ('Boenen', 'B', 1) = 8.0
#   ('Boenen', 'C', 1) = 10.0
#   ('Dortmund', 'A', 1) = 13.0
#   ('Dortmund', 'A', 2) = 6.0
#   ('Dortmund', 'B', 1) = 13.0
#   ('Dortmund', 'B', 2) = 8.0
#   ('Dortmund', 'C', 1) = 12.0
#   ('Dortmund', 'C', 2) = 6.0
#   ('Dortmund', 'C', 3) = 2.0
#   ('Gelsenkirchen', 'A', 2) = 5.0
#   ('Gelsenkirchen', 'B', 2) = 6.0
#   ('Gelsenkirchen', 'C', 2) = 9.0
#   ('Hagen', 'A', 3) = 14.0
#   ('Hagen', 'B', 1) = 4.0
#   ('Iserlohn', 'B', 1) = 3.0
#   ('Iserlohn', 'B', 2) = 1.0
#   ('Iserlohn', 'C', 3) = 7.0
#   ('Schwerte', 'A', 2) = 7.0
#   ('Schwerte', 'A', 3) = 4.0
#   ('Schwerte', 'B', 2) = 8.0
#   ('Schwerte', 'B', 3) = 6.0
#   ('Schwerte', 'C', 2) = 9.0
#   ('Schwerte', 'C', 3) = 2.0
#
# Variable: q
#   ('A', 'IJmuiden', 'Bochum', 1) = 8.0
#   ('A', 'IJmuiden', 'Dortmund', 4) = 5.0
#   ('A', 'IJmuiden', 'Gelsenkirchen', 1) = 5.0
#   ('A', 'IJmuiden', 'Gelsenkirchen', 2) = 10.0
#   ('A', 'IJmuiden', 'Hagen', 3) = 39.0
#   ('A', 'IJmuiden', 'Iserlohn', 4) = 14.0
#   ('A', 'IJmuiden', 'Neuss', 1) = 20.0
#   ('A', 'IJmuiden', 'Schwerte', 1) = 4.0
#   ('A', 'Segal', 'Boenen', 3) = 5.0
#   ('A', 'Segal', 'Boenen', 4) = 10.0
#   ('A', 'Segal', 'Gelsenkirchen', 4) = 5.0
#   ('A', 'Segal', 'Iserlohn', 1) = 13.0
#   ('A', 'Segal', 'Iserlohn', 3) = 17.0
#   ('A', 'Segal', 'Neuss', 2) = 16.0
#   ('A', 'South Wales', 'Bochum', 3) = 8.0
#   ('A', 'South Wales', 'Boenen', 1) = 12.0
#   ('A', 'South Wales', 'Dortmund', 1) = 15.0
#   ('A', 'South Wales', 'Hagen', 1) = 19.0
#   ('A', 'South Wales', 'Hagen', 2) = 23.0
#   ('A', 'South Wales', 'Hagen', 4) = 2.0
#   ('A', 'South Wales', 'Iserlohn', 2) = 19.0
#   ('A', 'South Wales', 'Neuss', 3) = 14.0
#   ('A', 'South Wales', 'Neuss', 4) = 26.0
#   ('A', 'South Wales', 'Schwerte', 2) = 12.0
#   ('B', 'IJmuiden', 'Bochum', 1) = 9.0
#   ('B', 'IJmuiden', 'Dortmund', 4) = 10.0
#   ('B', 'IJmuiden', 'Gelsenkirchen', 1) = 9.0
#   ('B', 'IJmuiden', 'Gelsenkirchen', 2) = 16.0
#   ('B', 'IJmuiden', 'Hagen', 3) = 31.0
#   ('B', 'IJmuiden', 'Iserlohn', 4) = 27.0
#   ('B', 'IJmuiden', 'Neuss', 1) = 12.0
#   ('B', 'IJmuiden', 'Schwerte', 1) = 2.0
#   ('B', 'Segal', 'Boenen', 3) = 12.0
#   ('B', 'Segal', 'Boenen', 4) = 13.0
#   ('B', 'Segal', 'Gelsenkirchen', 4) = 6.0
#   ('B', 'Segal', 'Iserlohn', 1) = 25.0
#   ('B', 'Segal', 'Iserlohn', 3) = 19.0
#   ('B', 'Segal', 'Neuss', 2) = 23.0
#   ('B', 'South Wales', 'Bochum', 3) = 15.0
#   ('B', 'South Wales', 'Boenen', 1) = 13.0
#   ('B', 'South Wales', 'Dortmund', 1) = 17.0
#   ('B', 'South Wales', 'Hagen', 1) = 19.0
#   ('B', 'South Wales', 'Hagen', 2) = 29.0
#   ('B', 'South Wales', 'Hagen', 4) = 33.0
#   ('B', 'South Wales', 'Iserlohn', 2) = 24.0
#   ('B', 'South Wales', 'Neuss', 3) = 30.0
#   ('B', 'South Wales', 'Neuss', 4) = 30.0
#   ('B', 'South Wales', 'Schwerte', 2) = 16.0
#   ('C', 'IJmuiden', 'Bochum', 1) = 13.0
#   ('C', 'IJmuiden', 'Dortmund', 4) = 10.0
#   ('C', 'IJmuiden', 'Gelsenkirchen', 1) = 10.0
#   ('C', 'IJmuiden', 'Gelsenkirchen', 2) = 18.0
#   ('C', 'IJmuiden', 'Hagen', 3) = 33.0
#   ('C', 'IJmuiden', 'Iserlohn', 4) = 17.0
#   ('C', 'IJmuiden', 'Neuss', 1) = 22.0
#   ('C', 'IJmuiden', 'Schwerte', 1) = 5.0
#   ('C', 'Segal', 'Boenen', 3) = 15.0
#   ('C', 'Segal', 'Boenen', 4) = 12.0
#   ('C', 'Segal', 'Gelsenkirchen', 4) = 10.0
#   ('C', 'Segal', 'Iserlohn', 1) = 14.0
#   ('C', 'Segal', 'Iserlohn', 3) = 30.0
#   ('C', 'Segal', 'Neuss', 2) = 32.0
#   ('C', 'South Wales', 'Bochum', 3) = 14.0
#   ('C', 'South Wales', 'Boenen', 1) = 16.0
#   ('C', 'South Wales', 'Dortmund', 1) = 19.0
#   ('C', 'South Wales', 'Hagen', 1) = 12.0
#   ('C', 'South Wales', 'Hagen', 2) = 35.0
#   ('C', 'South Wales', 'Hagen', 4) = 38.0
#   ('C', 'South Wales', 'Iserlohn', 2) = 25.0
#   ('C', 'South Wales', 'Neuss', 3) = 31.0
#   ('C', 'South Wales', 'Neuss', 4) = 31.0
#   ('C', 'South Wales', 'Schwerte', 2) = 15.0
#
# Variable: v
#   ('IJmuiden', 'Bochum', 2) = 1.0
#   ('IJmuiden', 'Bochum', 4) = 1.0
#   ('IJmuiden', 'Schwerte', 3) = 1.0
#   ('Segal', 'Bochum', 2) = 1.0
#   ('Segal', 'Bochum', 4) = 1.0
#   ('Segal', 'Dortmund', 3) = 1.0
#   ('Segal', 'Neuss', 1) = 1.0
#   ('South Wales', 'Bochum', 2) = 1.0
#   ('South Wales', 'Bochum', 4) = 1.0
#   ('South Wales', 'Gelsenkirchen', 3) = 1.0
#   ('Bochum', 'Dortmund', 1) = 1.0
#   ('Bochum', 'Dortmund', 2) = 1.0
#   ('Bochum', 'Gelsenkirchen', 2) = 1.0
#   ('Bochum', 'Gelsenkirchen', 4) = 1.0
#   ('Bochum', 'Neuss', 2) = 1.0
#   ('Bochum', 'Neuss', 3) = 1.0
#   ('Bochum', 'Neuss', 4) = 1.0
#   ('Bochum', 'Schwerte', 4) = 1.0
#   ('Boenen', 'IJmuiden', 3) = 1.0
#   ('Boenen', 'Segal', 1) = 1.0
#   ('Boenen', 'Segal', 2) = 1.0
#   ('Boenen', 'South Wales', 2) = 1.0
#   ('Boenen', 'South Wales', 4) = 1.0
#   ('Dortmund', 'Boenen', 3) = 1.0
#   ('Dortmund', 'Boenen', 4) = 1.0
#   ('Dortmund', 'Hagen', 1) = 1.0
#   ('Dortmund', 'Schwerte', 2) = 1.0
#   ('Gelsenkirchen', 'Bochum', 1) = 1.0
#   ('Gelsenkirchen', 'Bochum', 3) = 1.0
#   ('Gelsenkirchen', 'Boenen', 2) = 1.0
#   ('Gelsenkirchen', 'Schwerte', 4) = 1.0
#   ('Hagen', 'IJmuiden', 4) = 1.0
#   ('Hagen', 'Segal', 3) = 1.0
#   ('Hagen', 'Iserlohn', 1) = 1.0
#   ('Hagen', 'Iserlohn', 2) = 1.0
#   ('Iserlohn', 'Segal', 4) = 1.0
#   ('Iserlohn', 'South Wales', 3) = 1.0
#   ('Iserlohn', 'Boenen', 2) = 1.0
#   ('Iserlohn', 'Schwerte', 1) = 1.0
#   ('Neuss', 'IJmuiden', 2) = 1.0
#   ('Neuss', 'Gelsenkirchen', 1) = 1.0
#   ('Neuss', 'Schwerte', 3) = 1.0
#   ('Neuss', 'Schwerte', 4) = 1.0
#   ('Schwerte', 'Boenen', 1) = 1.0
#   ('Schwerte', 'Dortmund', 4) = 1.0
#   ('Schwerte', 'Hagen', 2) = 1.0
#   ('Schwerte', 'Hagen', 3) = 1.0
#   ('Schwerte', 'Hagen', 4) = 1.0
#   ('Schwerte', 'Iserlohn', 3) = 1.0
#   ('Schwerte', 'Iserlohn', 4) = 1.0
#
# Variable: u
#   ('Bochum', 'IJmuiden', 1) = 9.0
#   ('Bochum', 'South Wales', 3) = 4.0
#   ('Boenen', 'IJmuiden', 1) = 25.0
#   ('Boenen', 'IJmuiden', 2) = 25.0
#   ('Boenen', 'IJmuiden', 3) = 25.0
#   ('Boenen', 'IJmuiden', 4) = 25.0
#   ('Boenen', 'Segal', 1) = 20.0
#   ('Boenen', 'Segal', 2) = 25.0
#   ('Boenen', 'Segal', 3) = 16.0
#   ('Boenen', 'Segal', 4) = 25.0
#   ('Boenen', 'South Wales', 1) = 25.0
#   ('Boenen', 'South Wales', 2) = 25.0
#   ('Boenen', 'South Wales', 3) = 25.0
#   ('Boenen', 'South Wales', 4) = 25.0
#   ('Dortmund', 'IJmuiden', 1) = 9.0
#   ('Dortmund', 'IJmuiden', 2) = 25.0
#   ('Dortmund', 'IJmuiden', 3) = 25.0
#   ('Dortmund', 'IJmuiden', 4) = 2.0
#   ('Dortmund', 'Segal', 2) = 25.0
#   ('Dortmund', 'Segal', 3) = 13.0
#   ('Dortmund', 'Segal', 4) = 22.0
#   ('Dortmund', 'South Wales', 1) = 4.0
#   ('Dortmund', 'South Wales', 3) = 4.0
#   ('Dortmund', 'South Wales', 4) = 25.0
#   ('Gelsenkirchen', 'IJmuiden', 1) = 6.0
#   ('Gelsenkirchen', 'IJmuiden', 2) = 12.0
#   ('Gelsenkirchen', 'Segal', 4) = 2.0
#   ('Gelsenkirchen', 'South Wales', 3) = 1.0
#   ('Hagen', 'IJmuiden', 1) = 9.0
#   ('Hagen', 'IJmuiden', 2) = 25.0
#   ('Hagen', 'IJmuiden', 3) = 25.0
#   ('Hagen', 'Segal', 2) = 25.0
#   ('Hagen', 'Segal', 3) = 16.0
#   ('Hagen', 'Segal', 4) = 17.0
#   ('Hagen', 'South Wales', 1) = 8.0
#   ('Hagen', 'South Wales', 2) = 20.0
#   ('Hagen', 'South Wales', 3) = 25.0
#   ('Hagen', 'South Wales', 4) = 25.0
#   ('Iserlohn', 'IJmuiden', 1) = 9.0
#   ('Iserlohn', 'IJmuiden', 2) = 25.0
#   ('Iserlohn', 'IJmuiden', 3) = 25.0
#   ('Iserlohn', 'IJmuiden', 4) = 5.0
#   ('Iserlohn', 'Segal', 1) = 4.0
#   ('Iserlohn', 'Segal', 2) = 25.0
#   ('Iserlohn', 'Segal', 3) = 21.0
#   ('Iserlohn', 'Segal', 4) = 25.0
#   ('Iserlohn', 'South Wales', 1) = 8.0
#   ('Iserlohn', 'South Wales', 2) = 25.0
#   ('Iserlohn', 'South Wales', 3) = 25.0
#   ('Iserlohn', 'South Wales', 4) = 25.0
#   ('Neuss', 'IJmuiden', 1) = 4.0
#   ('Neuss', 'IJmuiden', 3) = 13.0
#   ('Neuss', 'Segal', 2) = 25.0
#   ('Neuss', 'Segal', 3) = 16.0
#   ('Neuss', 'South Wales', 3) = 25.0
#   ('Neuss', 'South Wales', 4) = 7.0
#   ('Schwerte', 'IJmuiden', 1) = 10.0
#   ('Schwerte', 'IJmuiden', 2) = 25.0
#   ('Schwerte', 'IJmuiden', 3) = 13.0
#   ('Schwerte', 'Segal', 1) = 20.0
#   ('Schwerte', 'Segal', 2) = 25.0
#   ('Schwerte', 'Segal', 3) = 16.0
#   ('Schwerte', 'Segal', 4) = 2.0
#   ('Schwerte', 'South Wales', 1) = 8.0
#   ('Schwerte', 'South Wales', 2) = 3.0
#   ('Schwerte', 'South Wales', 3) = 25.0
#   ('Schwerte', 'South Wales', 4) = 7.0

# %%
print(f"Objective Function Expression: {model3.obj.expr}")
# Out:
# Objective Function Expression: 3*z[IJmuiden,Bochum,1]*(250*v[IJmuiden,Bochum,1] + 203*v[Segal,Bochum,1] + 866*v[South Wales,Bochum,1] + 0*v[Bochum,Bochum,1] + 55*v[Boenen,Bochum,1] + 21*v[Dortmund,Bochum,1] + 19*v[Gelsenkirchen,Bochum,1] + 41*v[Hagen,Bochum,1] + 51*v[Iserlohn,Bochum,1] + 56*v[Neuss,Bochum,1] + 39*v[Schwerte,Bochum,1] + 250*v[Bochum,IJmuiden,1]) + 3*z[IJmuiden,Bochum,2]*(250*v[IJmuiden,Bochum,2] + 203*v[Segal,Bochum,2] + 866*v[South Wales,Bochum,2] + 0*v[Bochum,Bochum,2] + 55*v[Boenen,Bochum,2] + 21*v[Dortmund,Bochum,2] + 19*v[Gelsenkirchen,Bochum,2] + 41*v[Hagen,Bochum,2] + 51*v[Iserlohn,Bochum,2] + 56*v[Neuss,Bochum,2] + 39*v[Schwerte,Bochum,2] + 250*v[Bochum,IJmuiden,2]) + 3*z[IJmuiden,Bochum,3]*(250*v[IJmuiden,Bochum,3] + 203*v[Segal,Bochum,3] + 866*v[South Wales,Bochum,3] + 0*v[Bochum,Bochum,3] + 55*v[Boenen,Bochum,3] + 21*v[Dortmund,Bochum,3] + 19*v[Gelsenkirchen,Bochum,3] + 41*v[Hagen,Bochum,3] + 51*v[Iserlohn,Bochum,3] + 56*v[Neuss,Bochum,3] + 39*v[Schwerte,Bochum,3] + 250*v[Bochum,IJmuiden,3]) + 3*z[IJmuiden,Bochum,4]*(250*v[IJmuiden,Bochum,4] + 203*v[Segal,Bochum,4] + 866*v[South Wales,Bochum,4] + 0*v[Bochum,Bochum,4] + 55*v[Boenen,Bochum,4] + 21*v[Dortmund,Bochum,4] + 19*v[Gelsenkirchen,Bochum,4] + 41*v[Hagen,Bochum,4] + 51*v[Iserlohn,Bochum,4] + 56*v[Neuss,Bochum,4] + 39*v[Schwerte,Bochum,4] + 250*v[Bochum,IJmuiden,4]) + 3*z[IJmuiden,Boenen,1]*(282*v[IJmuiden,Boenen,1] + 242*v[Segal,Boenen,1] + 914*v[South Wales,Boenen,1] + 55*v[Bochum,Boenen,1] + 0*v[Boenen,Boenen,1] + 34*v[Dortmund,Boenen,1] + 56*v[Gelsenkirchen,Boenen,1] + 44*v[Hagen,Boenen,1] + 54*v[Iserlohn,Boenen,1] + 102*v[Neuss,Boenen,1] + 32*v[Schwerte,Boenen,1] + 282*v[Boenen,IJmuiden,1]) + 3*z[IJmuiden,Boenen,2]*(282*v[IJmuiden,Boenen,2] + 242*v[Segal,Boenen,2] + 914*v[South Wales,Boenen,2] + 55*v[Bochum,Boenen,2] + 0*v[Boenen,Boenen,2] + 34*v[Dortmund,Boenen,2] + 56*v[Gelsenkirchen,Boenen,2] + 44*v[Hagen,Boenen,2] + 54*v[Iserlohn,Boenen,2] + 102*v[Neuss,Boenen,2] + 32*v[Schwerte,Boenen,2] + 282*v[Boenen,IJmuiden,2]) + 3*z[IJmuiden,Boenen,3]*(282*v[IJmuiden,Boenen,3] + 242*v[Segal,Boenen,3] + 914*v[South Wales,Boenen,3] + 55*v[Bochum,Boenen,3] + 0*v[Boenen,Boenen,3] + 34*v[Dortmund,Boenen,3] + 56*v[Gelsenkirchen,Boenen,3] + 44*v[Hagen,Boenen,3] + 54*v[Iserlohn,Boenen,3] + 102*v[Neuss,Boenen,3] + 32*v[Schwerte,Boenen,3] + 282*v[Boenen,IJmuiden,3]) + 3*z[IJmuiden,Boenen,4]*(282*v[IJmuiden,Boenen,4] + 242*v[Segal,Boenen,4] + 914*v[South Wales,Boenen,4] + 55*v[Bochum,Boenen,4] + 0*v[Boenen,Boenen,4] + 34*v[Dortmund,Boenen,4] + 56*v[Gelsenkirchen,Boenen,4] + 44*v[Hagen,Boenen,4] + 54*v[Iserlohn,Boenen,4] + 102*v[Neuss,Boenen,4] + 32*v[Schwerte,Boenen,4] + 282*v[Boenen,IJmuiden,4]) + 3*z[IJmuiden,Dortmund,1]*(266*v[IJmuiden,Dortmund,1] + 222*v[Segal,Dortmund,1] + 885*v[South Wales,Dortmund,1] + 21*v[Bochum,Dortmund,1] + 34*v[Boenen,Dortmund,1] + 0*v[Dortmund,Dortmund,1] + 34*v[Gelsenkirchen,Dortmund,1] + 21*v[Hagen,Dortmund,1] + 36*v[Iserlohn,Dortmund,1] + 75*v[Neuss,Dortmund,1] + 15*v[Schwerte,Dortmund,1] + 266*v[Dortmund,IJmuiden,1]) + 3*z[IJmuiden,Dortmund,2]*(266*v[IJmuiden,Dortmund,2] + 222*v[Segal,Dortmund,2] + 885*v[South Wales,Dortmund,2] + 21*v[Bochum,Dortmund,2] + 34*v[Boenen,Dortmund,2] + 0*v[Dortmund,Dortmund,2] + 34*v[Gelsenkirchen,Dortmund,2] + 21*v[Hagen,Dortmund,2] + 36*v[Iserlohn,Dortmund,2] + 75*v[Neuss,Dortmund,2] + 15*v[Schwerte,Dortmund,2] + 266*v[Dortmund,IJmuiden,2]) + 3*z[IJmuiden,Dortmund,3]*(266*v[IJmuiden,Dortmund,3] + 222*v[Segal,Dortmund,3] + 885*v[South Wales,Dortmund,3] + 21*v[Bochum,Dortmund,3] + 34*v[Boenen,Dortmund,3] + 0*v[Dortmund,Dortmund,3] + 34*v[Gelsenkirchen,Dortmund,3] + 21*v[Hagen,Dortmund,3] + 36*v[Iserlohn,Dortmund,3] + 75*v[Neuss,Dortmund,3] + 15*v[Schwerte,Dortmund,3] + 266*v[Dortmund,IJmuiden,3]) + 3*z[IJmuiden,Dortmund,4]*(266*v[IJmuiden,Dortmund,4] + 222*v[Segal,Dortmund,4] + 885*v[South Wales,Dortmund,4] + 21*v[Bochum,Dortmund,4] + 34*v[Boenen,Dortmund,4] + 0*v[Dortmund,Dortmund,4] + 34*v[Gelse ...
