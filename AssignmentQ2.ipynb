# %%
import pyomo.environ as pe
import pyomo.opt as po
import math

# Data (same as Part 1)
factories = ["IJmuiden", "Segal", "South Wales"]
rebars = {"A": {"length": 2.4}, "B": {"length": 3.6}, "C": {"length": 4.2}}
longbars = {1: {"length": 9}, 2: {"length": 12}}
diameter = 0.057  # in meters
density = 7.85  # tons/m^3
production_capacity = {"IJmuiden": 12, "Segal": 10, "South Wales": 28}
customers = ["Bochum", "Boenen", "Dortmund", "Gelsenkirchen", "Hagen", "Iserlohn", "Neuss", "Schwerte"]
periods = [1, 2, 3, 4]

demand = {
    "A": {
        "Bochum": [2, 6, 5, 3],
        "Boenen": [4, 8, 5, 10],
        "Dortmund": [2, 7, 6, 5],
        "Gelsenkirchen": [5, 5, 5, 5],
        "Hagen": [19, 23, 25, 16],
        "Iserlohn": [13, 19, 17, 14],
        "Neuss": [20, 16, 14, 26],
        "Schwerte": [4, 5, 3, 4]
    },
    "B": {
        "Bochum": [4, 5, 7, 8],
        "Boenen": [5, 8, 12, 13],
        "Dortmund": [4, 5, 8, 10],
        "Gelsenkirchen": [9, 10, 6, 6],
        "Hagen": [15, 33, 31, 33],
        "Iserlohn": [22, 26, 20, 27],
        "Neuss": [12, 23, 30, 30],
        "Schwerte": [2, 8, 2, 6]
    },
    "C": {
        "Bochum": [6, 7, 7, 7],
        "Boenen": [6, 10, 15, 12],
        "Dortmund": [7, 6, 4, 12],
        "Gelsenkirchen": [10, 9, 9, 10],
        "Hagen": [12, 35, 33, 38],
        "Iserlohn": [14, 25, 23, 24],
        "Neuss": [22, 32, 31, 31],
        "Schwerte": [5, 6, 7, 2]
    }
}

fixed_cost = {"IJmuiden": 130, "Segal": 150, "South Wales": 100}
v = 0.5  # variable cost €/km/tonne
distance = {
    "Bochum": {"IJmuiden": 250, "Segal": 203, "South Wales": 866},
    "Boenen": {"IJmuiden": 282, "Segal": 242, "South Wales": 914},
    "Dortmund": {"IJmuiden": 266, "Segal": 222, "South Wales": 885},
    "Gelsenkirchen": {"IJmuiden": 234, "Segal": 198, "South Wales": 859},
    "Hagen": {"IJmuiden": 289, "Segal": 206, "South Wales": 903},
    "Iserlohn": {"IJmuiden": 299, "Segal": 226, "South Wales": 913},
    "Neuss": {"IJmuiden": 259, "Segal": 140, "South Wales": 843},
    "Schwerte": {"IJmuiden": 279, "Segal": 216, "South Wales": 901}
}

# New data: Inventory capacities (from Table 7)
inventory_capacity = {
    "Bochum": 10,
    "Boenen": 7,
    "Dortmund": 12,
    "Gelsenkirchen": 10,
    "Hagen": 12,
    "Iserlohn": 9,
    "Neuss": 8,
    "Schwerte": 5
}

# Precompute parameters
w_r = {r: rebars[r]["length"] for r in rebars}
w_l = {l: longbars[l]["length"] for l in longbars}
area = math.pi * (diameter / 2) ** 2
weight_r = {r: density * area * w_r[r] for r in rebars}

# Create the model
model = pe.ConcreteModel()

# Define sets
model.F = pe.Set(initialize=factories)
model.R = pe.Set(initialize=rebars.keys())
model.L = pe.Set(initialize=longbars.keys())
model.A = pe.Set(initialize=customers)
model.T = pe.Set(initialize=periods)

# Define variables
model.x = pe.Var(model.R, model.L, model.F, model.T, domain=pe.NonNegativeIntegers)
model.y = pe.Var(model.L, model.F, model.T, domain=pe.NonNegativeIntegers)
model.z = pe.Var(model.F, model.A, model.T, domain=pe.Binary)
model.q = pe.Var(model.R, model.F, model.T, domain=pe.NonNegativeIntegers)  # New: rebars shipped
model.s = pe.Var(model.R, model.A, model.T, domain=pe.NonNegativeReals)  # New: inventory

# Constraints using ConstraintList and for loops
# 1. Cutting constraints
model.cutting_cnstr = pe.ConstraintList()
for f in model.F:
    for t in model.T:
        for l in model.L:
            expression = sum(model.x[r, l, f, t] * w_r[r] for r in model.R) <= model.y[l, f, t] * w_l[l]
            model.cutting_cnstr.add(expression)

# 2. Production capacity
model.capacity_cnstr = pe.ConstraintList()
for f in model.F:
    for t in model.T:
        expression = sum(model.x[r, l, f, t] * weight_r[r] for r in model.R for l in model.L) <= production_capacity[f]
        model.capacity_cnstr.add(expression)

# 3. Single sourcing
model.single_sourcing_cnstr = pe.ConstraintList()
for a in model.A:
    for t in model.T:
        expression = sum(model.z[f, a, t] for f in model.F) == 1
        model.single_sourcing_cnstr.add(expression)

# 4. Rebars shipped from factory
model.shipment_cnstr = pe.ConstraintList()
for r in model.R:
    for f in model.F:
        for t in model.T:
            expression = sum(model.x[r, l, f, t] for l in model.L) == model.q[r, f, t]
            model.shipment_cnstr.add(expression)

# 5. Inventory balance constraints
model.inventory_balance_cnstr = pe.ConstraintList()
for r in model.R:
    for a in model.A:
        for t in model.T:
            if t == 1:
                # Starting inventory is zero
                expression = model.s[r, a, t] == sum(model.z[f, a, t] * model.q[r, f, t] for f in model.F) - demand[r][a][t-1]
            else:
                # Inventory evolves based on previous inventory, shipments, and demand
                expression = model.s[r, a, t] == model.s[r, a, t-1] + sum(model.z[f, a, t] * model.q[r, f, t] for f in model.F) - demand[r][a][t-1]
            model.inventory_balance_cnstr.add(expression)

# 6. Inventory capacity constraints
model.inventory_capacity_cnstr = pe.ConstraintList()
for a in model.A:
    for t in model.T:
        expression = sum(model.s[r, a, t] * weight_r[r] for r in model.R) <= inventory_capacity[a]
        model.inventory_capacity_cnstr.add(expression)

# Objective function
objExpr = sum(fixed_cost[f] * model.z[f, a, t] for f in model.F for a in model.A for t in model.T) + \
          sum(v * distance[a][f] * model.z[f, a, t] * sum(model.q[r, f, t] * weight_r[r] for r in model.R)
              for f in model.F for a in model.A for t in model.T)
model.obj = pe.Objective(expr=objExpr, sense=pe.minimize)

# Solve the model
solver = pe.SolverFactory('gurobi')
result = solver.solve(model, tee=True)

# Display results
print(f"\nSolver Status: {result.solver.status}")
print(f"Termination Condition: {result.solver.termination_condition}")
if result.solver.status == po.SolverStatus.ok and result.solver.termination_condition == po.TerminationCondition.optimal:
    print(f"Objective value (Total Cost): {pe.value(model.obj):.2f} €")
    print("\nFactory assignments (z[f,a,t] = 1):")
    for f in model.F:
        for a in model.A:
            for t in model.T:
                if pe.value(model.z[f, a, t]) > 0.5:
                    print(f"z[{f}, {a}, {t}] = 1")
    print("\nRebars shipped (q[r,f,t] > 0):")
    for r in model.R:
        for f in model.F:
            for t in model.T:
                if pe.value(model.q[r, f, t]) > 0:
                    print(f"q[{r}, {f}, {t}] = {pe.value(model.q[r, f, t]):.0f}")
    print("\nInventory levels (s[r,a,t] > 0):")
    for r in model.R:
        for a in model.A:
            for t in model.T:
                if pe.value(model.s[r, a, t]) > 0:
                    print(f"s[{r}, {a}, {t}] = {pe.value(model.s[r, a, t]):.2f}")
    print("\nRebars cut (x[r,l,f,t] > 0):")
    for r in model.R:
        for l in model.L:
            for f in model.F:
                for t in model.T:
                    if pe.value(model.x[r, l, f, t]) > 0:
                        print(f"x[{r}, {l}, {f}, {t}] = {pe.value(model.x[r, l, f, t]):.0f}")
    print("\nLong bars used (y[l,f,t] > 0):")
    for l in model.L:
        for f in model.F:
            for t in model.T:
                if pe.value(model.y[l, f, t]) > 0:
                    print(f"y[{l}, {f}, {t}] = {pe.value(model.y[l, f, t]):.0f}")
else:
    print("No optimal solution found.")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2617608
# Academic license - for non-commercial use only - expires 2026-02-03
# Read LP format model from file C:\Users\User\AppData\Local\Temp\tmpngod6nd4.pyomo.lp
# Reading time = 0.02 seconds
# x1: 136 rows, 324 columns, 468 nonzeros
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1255U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 136 rows, 324 columns and 468 nonzeros
# Model fingerprint: 0x73e01c3e
# Model has 288 quadratic objective terms
# Model has 96 quadratic constraints
# Variable types: 96 continuous, 228 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+01]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+02, 2e+02]
#   QObjective range [7e+00, 8e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [2e+00, 4e+01]
# Presolve removed 60 rows and 96 columns
# Presolve time: 0.00s
# Presolved: 1036 rows, 516 columns, 2700 nonzeros
# Variable types: 0 continuous, 516 integer (96 binary)
#
# Root relaxation: objective 1.207354e+04, 257 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 12073.5421    0   90          - 12073.5421      -     -    0s
# H    0     0                    31338.099297 12073.5421  61.5%     -    0s
# H    0     0                    31247.784150 12073.5421  61.4%     -    0s
#      0     0 12352.0513    0   97 31247.7842 12352.0513  60.5%     -    0s
# H    0     0                    22507.060549 12353.5438  45.1%     -    0s
# H    0     0                    20496.623488 12353.5438  39.7%     -    0s
#      0     0 12380.4212    0  123 20496.6235 12380.4212  39.6%     -    0s
#      0     0 12384.3926    0  127 20496.6235 12384.3926  39.6%     -    0s
#      0     0 12462.0185    0  171 20496.6235 12462.0185  39.2%     -    0s
# H    0     0                    20354.004460 12467.4842  38.7%     -    0s
#      0     0 12467.4842    0  169 20354.0045 12467.4842  38.7%     -    0s
# H    0     0                    13556.044350 12467.4842  8.03%     -    0s
# H    0     0                    13344.488612 12467.4842  6.57%     -    0s
#      0     0 12487.5193    0  159 13344.4886 12487.5193  6.42%     -    0s
#      0     0 12497.1485    0  151 13344.4886 12497.1485  6.35%     -    0s
#      0     0 12497.7351    0  148 13344.4886 12497.7351  6.35%     -    0s
# H    0     0                    13311.052357 12497.7351  6.11%     -    0s
#      0     0 12509.4398    0  141 13311.0524 12509.4398  6.02%     -    0s
#      0     0 12512.3451    0  147 13311.0524 12512.3451  6.00%     -    0s
# H    0     0                    13185.190543 12512.3451  5.10%     -    0s
#      0     0 12518.3636    0  149 13185.1905 12518.3636  5.06%     -    0s
# H    0     0                    13109.978860 12518.3636  4.51%     -    0s
#      0     0 12518.9876    0  149 13109.9789 12518.9876  4.51%     -    0s
# H    0     0                    13095.434270 12523.2789  4.37%     -    0s
# H    0     0                    13069.113135 12523.2789  4.18%     -    0s
#      0     2 12523.2789    0  146 13069.1131 12523.2789  4.18%     -    0s
# H  225   234                    13045.245694 12631.2950  3.17%  26.9    0s
# H  336   323                    12896.777665 12645.5167  1.95%  25.8    0s
# H 1946   514                    12886.751393 12769.6314  0.91%  24.0    0s
# * 3416    36              31    12886.312708 12835.4452  0.39%  23.7    0s
#
# Cutting planes:
#   Gomory: 6
#   Implied bound: 67
#   MIR: 89
#   StrongCG: 7
#   Flow cover: 29
#   Flow path: 92
#   Inf proof: 5
#   RLT: 23
#   Relax-and-lift: 15
#   PSD: 3
#
# Explored 3574 nodes (83902 simplex iterations) in 0.97 seconds (0.71 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 12886.3 12886.8 12896.8 ... 13344.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.288631270758e+04, best bound 1.288631270758e+04, gap 0.0000%
#
# Solver Status: ok
# Termination Condition: optimal
# Objective value (Total Cost): 12886.31 €
#
# Factory assignments (z[f,a,t] = 1):
# z[IJmuiden, Boenen, 2] = 1
# z[IJmuiden, Gelsenkirchen, 4] = 1
# z[IJmuiden, Iserlohn, 3] = 1
# z[IJmuiden, Schwerte, 1] = 1
# z[Segal, Bochum, 1] = 1
# z[Segal, Boenen, 1] = 1
# z[Segal, Dortmund, 1] = 1
# z[Segal, Gelsenkirchen, 1] = 1
# z[Segal, Hagen, 1] = 1
# z[Segal, Hagen, 2] = 1
# z[Segal, Hagen, 3] = 1
# z[Segal, Iserlohn, 1] = 1
# z[Segal, Iserlohn, 2] = 1
# z[Segal, Neuss, 1] = 1
# z[Segal, Neuss, 2] = 1
# z[Segal, Neuss, 4] = 1
# z[South Wales, Bochum, 2] = 1
# z[South Wales, Bochum, 3] = 1
# z[South Wales, Bochum, 4] = 1
# z[South Wales, Boenen, 3] = 1
# z[South Wales, Boenen, 4] = 1
# z[South Wales, Dortmund, 2] = 1
# z[South Wales, Dortmund, 3] = 1
# z[South Wales, Dortmund, 4] = 1
# z[South Wales, Gelsenkirchen, 2] = 1
# z[South Wales, Gelsenkirchen, 3] = 1
# z[South Wales, Hagen, 4] = 1
# z[South Wales, Iserlohn, 4] = 1
# z[South Wales, Neuss, 3] = 1
# z[South Wales, Schwerte, 2] = 1
# z[South Wales, Schwerte, 3] = 1
# z[South Wales, Schwerte, 4] = 1
#
# Rebars shipped (q[r,f,t] > 0):
# q[A, IJmuiden, 1] = 16
# q[A, IJmuiden, 2] = 7
# q[A, IJmuiden, 3] = 2
# q[A, Segal, 1] = 20
# q[A, Segal, 2] = 41
# q[A, Segal, 3] = 22
# q[A, Segal, 4] = 15
# q[A, South Wales, 1] = 23
# q[B, IJmuiden, 1] = 18
# q[B, IJmuiden, 2] = 11
# q[B, IJmuiden, 3] = 22
# q[B, IJmuiden, 4] = 4
# q[B, Segal, 1] = 27
# q[B, Segal, 2] = 46
# q[B, Segal, 3] = 39
# q[B, Segal, 4] = 22
# q[B, South Wales, 1] = 16
# q[C, IJmuiden, 1] = 20
# q[C, IJmuiden, 2] = 14
# q[C, IJmuiden, 3] = 1
# q[C, IJmuiden, 4] = 9
# q[C, Segal, 1] = 29
# q[C, Segal, 2] = 56
# q[C, Segal, 3] = 33
# q[C, Segal, 4] = 31
# q[C, South Wales, 1] = 28
#
# Inventory levels (s[r,a,t] > 0):
# s[A, Bochum, 1] = 18.00
# s[A, Bochum, 2] = 12.00
# s[A, Bochum, 3] = 7.00
# s[A, Bochum, 4] = 4.00
# s[A, Boenen, 1] = 16.00
# s[A, Boenen, 2] = 15.00
# s[A, Boenen, 3] = 10.00
# s[A, Dortmund, 1] = 18.00
# s[A, Dortmund, 2] = 11.00
# s[A, Dortmund, 3] = 5.00
# s[A, Gelsenkirchen, 1] = 15.00
# s[A, Gelsenkirchen, 2] = 10.00
# s[A, Gelsenkirchen, 3] = 5.00
# s[A, Hagen, 1] = 1.00
# s[A, Hagen, 2] = 19.00
# s[A, Hagen, 3] = 16.00
# s[A, Iserlohn, 1] = 7.00
# s[A, Iserlohn, 2] = 29.00
# s[A, Iserlohn, 3] = 14.00
# s[A, Neuss, 2] = 25.00
# s[A, Neuss, 3] = 11.00
# s[A, Schwerte, 1] = 12.00
# s[A, Schwerte, 2] = 7.00
# s[A, Schwerte, 3] = 4.00
# s[B, Bochum, 1] = 23.00
# s[B, Bochum, 2] = 18.00
# s[B, Bochum, 3] = 11.00
# s[B, Bochum, 4] = 3.00
# s[B, Boenen, 1] = 22.00
# s[B, Boenen, 2] = 25.00
# s[B, Boenen, 3] = 13.00
# s[B, Dortmund, 1] = 23.00
# s[B, Dortmund, 2] = 18.00
# s[B, Dortmund, 3] = 10.00
# s[B, Gelsenkirchen, 1] = 18.00
# s[B, Gelsenkirchen, 2] = 8.00
# s[B, Gelsenkirchen, 3] = 2.00
# s[B, Hagen, 1] = 12.00
# s[B, Hagen, 2] = 25.00
# s[B, Hagen, 3] = 33.00
# s[B, Iserlohn, 1] = 5.00
# s[B, Iserlohn, 2] = 25.00
# s[B, Iserlohn, 3] = 27.00
# s[B, Neuss, 1] = 15.00
# s[B, Neuss, 2] = 38.00
# s[B, Neuss, 3] = 8.00
# s[B, Schwerte, 1] = 16.00
# s[B, Schwerte, 2] = 8.00
# s[B, Schwerte, 3] = 6.00
# s[C, Bochum, 1] = 23.00
# s[C, Bochum, 2] = 16.00
# s[C, Bochum, 3] = 9.00
# s[C, Bochum, 4] = 2.00
# s[C, Boenen, 1] = 23.00
# s[C, Boenen, 2] = 27.00
# s[C, Boenen, 3] = 12.00
# s[C, Dortmund, 1] = 22.00
# s[C, Dortmund, 2] = 16.00
# s[C, Dortmund, 3] = 12.00
# s[C, Gelsenkirchen, 1] = 19.00
# s[C, Gelsenkirchen, 2] = 10.00
# s[C, Gelsenkirchen, 3] = 1.00
# s[C, Hagen, 1] = 17.00
# s[C, Hagen, 2] = 38.00
# s[C, Hagen, 3] = 38.00
# s[C, Iserlohn, 1] = 15.00
# s[C, Iserlohn, 2] = 46.00
# s[C, Iserlohn, 3] = 24.00
# s[C, Neuss, 1] = 7.00
# s[C, Neuss, 2] = 31.00
# s[C, Schwerte, 1] = 15.00
# s[C, Schwerte, 2] = 9.00
# s[C, Schwerte, 3] = 2.00
#
# Rebars cut (x[r,l,f,t] > 0):
# x[A, 1, IJmuiden, 1] = 16
# x[A, 1, IJmuiden, 2] = 7
# x[A, 1, IJmuiden, 3] = 2
# x[A, 1, Segal, 1] = 20
# x[A, 1, South Wales, 1] = 23
# x[A, 2, Segal, 2] = 41
# x[A, 2, Segal, 3] = 22
# x[A, 2, Segal, 4] = 15
# x[B, 1, IJmuiden, 2] = 11
# x[B, 1, IJmuiden, 3] = 22
# x[B, 1, IJmuiden, 4] = 4
# x[B, 1, South Wales, 1] = 16
# x[B, 2, IJmuiden, 1] = 18
# x[B, 2, Segal, 1] = 27
# x[B, 2, Segal, 2] = 46
# x[B, 2, Segal, 3] = 39
# x[B, 2, Segal, 4] = 22
# x[C, 1, IJmuiden, 2] = 14
# x[C, 1, IJmuiden, 3] = 1
# x[C, 1, IJmuiden, 4] = 9
# x[C, 1, Segal, 4] = 31
# x[C, 2, IJmuiden, 1] = 20
# x[C, 2, Segal, 1] = 29
# x[C, 2, Segal, 2] = 56
# x[C, 2, Segal, 3] = 33
# x[C, 2, South Wales, 1] = 28
#
# Long bars used (y[l,f,t] > 0):
# y[1, IJmuiden, 1] = 5
# y[1, IJmuiden, 2] = 13
# y[1, IJmuiden, 3] = 10
# y[1, IJmuiden, 4] = 6
# y[1, Segal, 1] = 6
# y[1, Segal, 4] = 15
# y[1, South Wales, 1] = 13
# y[2, IJmuiden, 1] = 13
# y[2, Segal, 1] = 19
# y[2, Segal, 2] = 42
# y[2, Segal, 3] = 28
# y[2, Segal, 4] = 10
# y[2, South Wales, 1] = 10
